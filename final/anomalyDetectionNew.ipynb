# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import plotly.graph_objects as go

from scipy.fft import fft
from scipy.signal import butter,filtfilt

import time

# %matplotlib widget

# %%
def modifyTimestamps(df):

    df = df.dropna()
    df = df.drop(df.filter(regex='Name..').columns, axis=1)
    df = df.rename(columns={"Name": "Time"})

    return df


def LDAP_to_time(t_array):

    timestamp_array = []

    for timestamp in t_array:

        if type(timestamp) == pd._libs.tslibs.timestamps.Timestamp:
            timestamp_array.append(timestamp)

        else:
            value = datetime.datetime(1601, 1, 1) + datetime.timedelta(seconds=timestamp/10000000)
            timestamp_array.append(value)

    return np.asarray(timestamp_array)

# %%
def lowpass_filter(signal, cutoff, fs, order):

    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq

    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, signal)
    
    return y

# %%
def rms_variation(V_array, T_array, anomaly_meta_info):

    # Beginning to end: 4000 values
    # Shifting the window by every 200 values
    for i in np.arange(start=0, stop=len(V_array), step=200):

        # taking 400 values at a time to calculate RMS
        start = i
        end = i + 400

        # RMS calculation
        V_rms = np.sqrt(np.mean(np.square(V_array[start:end])))



        if (V_rms >= 1.1 * anomaly_meta_info['voltage_threshold']):

            # swell start
            if (anomaly_meta_info['swell_start'] == None) and (anomaly_meta_info['swell_end'] == None):
                anomaly_meta_info['swell_start'] = T_array[i]
                print(f"Swell Start: {anomaly_meta_info['swell_start']}")


            if (V_rms >= anomaly_meta_info['max_swell_value']):
                anomaly_meta_info['max_swell_value'] = V_rms



        if (V_rms < 1.1 * anomaly_meta_info['voltage_threshold']) and (V_rms >= 0.9 * anomaly_meta_info['voltage_threshold']):

            # sag end
            if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_end'] = T_array[i]
                print(f"Sag End: {anomaly_meta_info['sag_end']}")


            # swell end
            if (anomaly_meta_info['swell_start'] != None) and (anomaly_meta_info['swell_end'] == None):
                anomaly_meta_info['swell_end'] = T_array[i]
                print(f"Swell End: {anomaly_meta_info['swell_end']}")


                
        if (V_rms < 0.9 * anomaly_meta_info['voltage_threshold']) and (V_rms >= 0.1 * anomaly_meta_info['voltage_threshold']):

            # sag start
            if (anomaly_meta_info['sag_start'] == None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_start'] = T_array[i]
                print(f"Sag Start: {anomaly_meta_info['sag_start']}")


            if (V_rms <= anomaly_meta_info['min_sag_value']):
                anomaly_meta_info['min_sag_value'] = V_rms


            # interruption end
            if (anomaly_meta_info['interruption_start'] != None) and (anomaly_meta_info['interruption_end'] == None):
                anomaly_meta_info['interruption_end'] = T_array[i]
                print(f"Interruption End: {anomaly_meta_info['interruption_end']}")


        
        if (V_rms < 0.1 * anomaly_meta_info['voltage_threshold']):

            # sag end
            if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_end'] = T_array[i]
                print(f"Sag End: {anomaly_meta_info['sag_end']}")


            # interruption start
            if (anomaly_meta_info['interruption_start'] == None) and (anomaly_meta_info['interruption_end'] == None):
                anomaly_meta_info['interruption_start'] = T_array[i]
                print(f"Interruption Start: {anomaly_meta_info['interruption_start']}")



        # reporting detected sag
        if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] != None):
            sag_duration = anomaly_meta_info['sag_end'] - anomaly_meta_info['sag_start']

            print("\n*********************************************************************************")
            print(f"Sag Duration: {sag_duration}")
            print(f"Retained Voltage: {anomaly_meta_info['min_sag_value']}")

            if (sag_duration <= datetime.timedelta(seconds=0.599853)): print(f"Sag Type: Instantaneous")
            elif (sag_duration > datetime.timedelta(seconds=0.599853)) and (sag_duration <= datetime.timedelta(seconds=3)): print(f"Sag Type: Momentary")
            elif (sag_duration > datetime.timedelta(seconds=3)) and (sag_duration <= datetime.timedelta(minutes=1)): print(f"Sag Type: Temporary")
            elif (sag_duration > datetime.timedelta(minutes=1)): print(f"Sag Type: Long Term Undervoltage")
            print("*********************************************************************************")

            anomaly_meta_info['sag_start'] = None
            anomaly_meta_info['sag_end'] = None
            anomaly_meta_info['min_sag_value'] = 1000000.



        # reporting detected swell
        if (anomaly_meta_info['swell_start'] != None) and (anomaly_meta_info['swell_end'] != None):
            swell_duration = anomaly_meta_info['swell_end'] - anomaly_meta_info['swell_start']

            print("\n*********************************************************************************")
            print(f"Swell Duration: {swell_duration}")
            print(f"Retained Voltage: {anomaly_meta_info['max_swell_value']}")

            if (swell_duration <= datetime.timedelta(seconds=0.599853)): print(f"Swell Type: Instantaneous")
            elif (swell_duration > datetime.timedelta(seconds=0.599853)) and (swell_duration <= datetime.timedelta(seconds=3)): print(f"Swell Type: Momentary")
            elif (swell_duration > datetime.timedelta(seconds=3)) and (swell_duration <= datetime.timedelta(minutes=1)): print(f"Swell Type: Temporary")
            elif (swell_duration > datetime.timedelta(minutes=1)): print(f"Swell Type: Long Term Overvoltage")
            print("*********************************************************************************")

            anomaly_meta_info['swell_start'] = None
            anomaly_meta_info['swell_end'] = None
            anomaly_meta_info['max_swell_value'] = 0.



        # reporting detected interruption
        if (anomaly_meta_info['interruption_start'] != None) and (anomaly_meta_info['interruption_end'] != None):
            interruption_duration = anomaly_meta_info['interruption_end'] - anomaly_meta_info['interruption_start']

            print("\n*********************************************************************************")
            print(f"Interruption Duration: {interruption_duration}")

            if (interruption_duration <= datetime.timedelta(seconds=3)): print(f"Interruption Type: Momentary")
            elif (interruption_duration > datetime.timedelta(seconds=3)) and (interruption_duration <= datetime.timedelta(minutes=1)): print(f"Interruption Type: Temporary")
            elif (interruption_duration > datetime.timedelta(minutes=1)): print(f"Interruption Type: Long Term Sustained Interruption")
            print("*********************************************************************************")

            anomaly_meta_info['interruption_start'] = None
            anomaly_meta_info['interruption_end'] = None



    return anomaly_meta_info

# %%
def thd_variation(signal, anomaly_meta_info, fs=20000):

    # Taking FFT of the signal
    X = fft(signal)
    N = len(X)
    n = np.arange(N)
    T = N/fs

    # Considering only half due to FFT 
    freq = (n/T)[1:int(N/2)] 
    freq_amplitudes = np.abs(X)[1:int(N/2)]

    # Sorting frequencies based on detected amplitudes
    sorted_indices = np.argsort(-freq_amplitudes)

    # Getting first frequency as dominant
    dominant_freq = freq[sorted_indices[0]]
    other_freq = freq[sorted_indices[1:]]

    anomaly_meta_info['dominant_freq'] = dominant_freq


    # Squaring amplitudes other than prime frequency
    sq_sum = np.sum(np.square(freq_amplitudes))

    # Squaring amplitude of prime frequency
    sq_prime = np.square(np.max(freq_amplitudes))
    sq_harmonics = sq_sum - sq_prime

    # Calculating THD
    thd = 100 * np.sqrt(sq_harmonics / sq_prime)

    anomaly_meta_info['thd'] = thd


    # Reporting detected prime harmonic variation
    if (dominant_freq != anomaly_meta_info['required_freq']): 

        print("\n*********************************************************************************")
        print(f"Prime Harmonic Variation")
        print(f"Dominant Frequency: {anomaly_meta_info['dominant_freq']}")
        print("*********************************************************************************")

    
    # Reporting detected THD variation
    if (thd > anomaly_meta_info['thd_threshold']): 
        
        print("\n*********************************************************************************")
        print(f"THD Threshold Violated")
        print(f"THD: {anomaly_meta_info['thd']} %")
        print("*********************************************************************************")


    return anomaly_meta_info

# %%
def anomaly_detection(V_array, I_array, T_array, anomaly_meta_info):

    print(f'\n10 cycles received at: {T_array[0]}')


    V1_filt = lowpass_filter(signal=V_array, cutoff=500, fs=20000, order=2)
    I1_filt = lowpass_filter(signal=I_array, cutoff=500, fs=20000, order=2)


    anomaly_meta_info = rms_variation(V_array=V1_filt, T_array=T_array, anomaly_meta_info=anomaly_meta_info)
    anomaly_meta_info = thd_variation(signal=V1_filt, anomaly_meta_info=anomaly_meta_info)


    return anomaly_meta_info

# %%
df = pd.read_csv('data/03_Voltage surge.csv', sep=';')
df = modifyTimestamps(df=df)

factor = 192.76315789473685

V1_complete = df['U_L1real'].iloc[:].to_numpy() * factor
I1_complete = df['I_L1real'].iloc[:].to_numpy()
T_complete = df['Time'].iloc[:].to_numpy()


anomaly_meta_info = {
    'voltage_threshold': 230.,

    'swell_start': None,
    'swell_end': None,
    'max_swell_value': 0.,

    'sag_start': None,
    'sag_end': None,
    'min_sag_value': 1000000.,

    'interruption_start': None,
    'interruption_end': None,

    'required_freq': 50.,
    'dominant_freq': None,

    'thd_threshold': 8.,
    'thd': None,
}

# %%
for i in np.arange(start=0, stop=len(V1_complete), step=4000):

    start = i
    end = start + 4000

    V1 = V1_complete[start:end]
    I1 = I1_complete[start:end]

    T1 = T_complete[start:end]
    T1 = LDAP_to_time(t_array=T1)

    if len(V1) >= 400:
        anomaly_meta_info = anomaly_detection(V_array=V1, I_array=I1, T_array=T1, anomaly_meta_info=anomaly_meta_info)

    # time.sleep(2)
# Out:
# 10 cycles received at: 2024-03-12 11:35:19.209000
#
# 10 cycles received at: 2024-03-12 11:35:19.409000
#
# 10 cycles received at: 2024-03-12 11:35:19.608999
#
# 10 cycles received at: 2024-03-12 11:35:19.809000
#
# 10 cycles received at: 2024-03-12 11:35:20.009001
#
# 10 cycles received at: 2024-03-12 11:35:20.209000
#
# 10 cycles received at: 2024-03-12 11:35:20.409000
#
# 10 cycles received at: 2024-03-12 11:35:20.608999
#
# 10 cycles received at: 2024-03-12 11:35:20.809000
#
# 10 cycles received at: 2024-03-12 11:35:21.009001
#
# 10 cycles received at: 2024-03-12 11:35:21.209000
#
# 10 cycles received at: 2024-03-12 11:35:21.409000
#
# 10 cycles received at: 2024-03-12 11:35:21.608999
#
# 10 cycles received at: 2024-03-12 11:35:21.809000
#
# 10 cycles received at: 2024-03-12 11:35:22.009001
#
# 10 cycles received at: 2024-03-12 11:35:22.209000
#
# 10 cycles received at: 2024-03-12 11:35:22.409000
#
# 10 cycles received at: 2024-03-12 11:35:22.608999
#
# 10 cycles received at: 2024-03-12 11:35:22.809000
#
# 10 cycles received at: 2024-03-12 11:35:23.009001
#
# 10 cycles received at: 2024-03-12 11:35:23.209000
#
# 10 cycles received at: 2024-03-12 11:35:23.409000
#
# 10 cycles received at: 2024-03-12 11:35:23.608999
#
# 10 cycles received at: 2024-03-12 11:35:23.809000
#
# 10 cycles received at: 2024-03-12 11:35:24.009001
#
# 10 cycles received at: 2024-03-12 11:35:24.209000
#
# 10 cycles received at: 2024-03-12 11:35:24.409000
#
# 10 cycles received at: 2024-03-12 11:35:24.608999
#
# 10 cycles received at: 2024-03-12 11:35:24.809000
#
# 10 cycles received at: 2024-03-12 11:35:25.009001
#
# 10 cycles received at: 2024-03-12 11:35:25.209000
#
# 10 cycles received at: 2024-03-12 11:35:25.409000
#
# 10 cycles received at: 2024-03-12 11:35:25.608999
#
# 10 cycles received at: 2024-03-12 11:35:25.809000
#
# 10 cycles received at: 2024-03-12 11:35:26.009001
#
# 10 cycles received at: 2024-03-12 11:35:26.209000
#
# 10 cycles received at: 2024-03-12 11:35:26.409000
#
# 10 cycles received at: 2024-03-12 11:35:26.608999
#
# 10 cycles received at: 2024-03-12 11:35:26.809000
#
# 10 cycles received at: 2024-03-12 11:35:27.009001
#
# 10 cycles received at: 2024-03-12 11:35:27.209000
#
# 10 cycles received at: 2024-03-12 11:35:27.409000
#
# 10 cycles received at: 2024-03-12 11:35:27.608999
#
# 10 cycles received at: 2024-03-12 11:35:27.809000
#
# 10 cycles received at: 2024-03-12 11:35:28.009001
#
# 10 cycles received at: 2024-03-12 11:35:28.209000
#
# 10 cycles received at: 2024-03-12 11:35:28.409000
#
# 10 cycles received at: 2024-03-12 11:35:28.608999
#
# 10 cycles received at: 2024-03-12 11:35:28.809000
#
# 10 cycles received at: 2024-03-12 11:35:29.009001
#
# 10 cycles received at: 2024-03-12 11:35:29.209000
#
# 10 cycles received at: 2024-03-12 11:35:29.409000
#
# 10 cycles received at: 2024-03-12 11:35:29.608999
#
# 10 cycles received at: 2024-03-12 11:35:29.809000
#
# 10 cycles received at: 2024-03-12 11:35:30.009001
#
# 10 cycles received at: 2024-03-12 11:35:30.209000
#
# 10 cycles received at: 2024-03-12 11:35:30.409000
#
# 10 cycles received at: 2024-03-12 11:35:30.608999
#
# 10 cycles received at: 2024-03-12 11:35:30.809000
#
# 10 cycles received at: 2024-03-12 11:35:31.009001
#
# 10 cycles received at: 2024-03-12 11:35:31.209000
#
# 10 cycles received at: 2024-03-12 11:35:31.409000
#
# 10 cycles received at: 2024-03-12 11:35:31.608999
#
# 10 cycles received at: 2024-03-12 11:35:31.809000
#
# 10 cycles received at: 2024-03-12 11:35:32.009001
#
# 10 cycles received at: 2024-03-12 11:35:32.209000
#
# 10 cycles received at: 2024-03-12 11:35:32.409000
#
# 10 cycles received at: 2024-03-12 11:35:32.608999
#
# 10 cycles received at: 2024-03-12 11:35:32.809000
#
# 10 cycles received at: 2024-03-12 11:35:33.009001
#
# 10 cycles received at: 2024-03-12 11:35:33.209000
#
# 10 cycles received at: 2024-03-12 11:35:33.409000
#
# 10 cycles received at: 2024-03-12 11:35:33.608999
#
# 10 cycles received at: 2024-03-12 11:35:33.809000
#
# 10 cycles received at: 2024-03-12 11:35:34.009001
#
# 10 cycles received at: 2024-03-12 11:35:34.209000
#
# 10 cycles received at: 2024-03-12 11:35:34.409000
#
# 10 cycles received at: 2024-03-12 11:35:34.608999
#
# 10 cycles received at: 2024-03-12 11:35:34.809000
#
# 10 cycles received at: 2024-03-12 11:35:35.009001
#
# 10 cycles received at: 2024-03-12 11:35:35.209000
#
# 10 cycles received at: 2024-03-12 11:35:35.409000
#
# 10 cycles received at: 2024-03-12 11:35:35.608999
#
# 10 cycles received at: 2024-03-12 11:35:35.809000
#
# 10 cycles received at: 2024-03-12 11:35:36.009001
#
# 10 cycles received at: 2024-03-12 11:35:36.209000
#
# 10 cycles received at: 2024-03-12 11:35:36.409000
#
# 10 cycles received at: 2024-03-12 11:35:36.608999
#
# 10 cycles received at: 2024-03-12 11:35:36.809000
#
# 10 cycles received at: 2024-03-12 11:35:37.009001
#
# 10 cycles received at: 2024-03-12 11:35:37.209000
#
# 10 cycles received at: 2024-03-12 11:35:37.409000
#
# 10 cycles received at: 2024-03-12 11:35:37.608999
#
# 10 cycles received at: 2024-03-12 11:35:37.809000
#
# 10 cycles received at: 2024-03-12 11:35:38.009001
#
# 10 cycles received at: 2024-03-12 11:35:38.209000
#
# 10 cycles received at: 2024-03-12 11:35:38.409000
#
# 10 cycles received at: 2024-03-12 11:35:38.608999
#
# 10 cycles received at: 2024-03-12 11:35:38.809000
#
# 10 cycles received at: 2024-03-12 11:35:39.009001
#
# 10 cycles received at: 2024-03-12 11:35:39.209000
#
# 10 cycles received at: 2024-03-12 11:35:39.409000
#
# 10 cycles received at: 2024-03-12 11:35:39.608999
#
# 10 cycles received at: 2024-03-12 11:35:39.809000
#
# 10 cycles received at: 2024-03-12 11:35:40.009001
#
# 10 cycles received at: 2024-03-12 11:35:40.209000
#
# 10 cycles received at: 2024-03-12 11:35:40.409000
#
# 10 cycles received at: 2024-03-12 11:35:40.608999
#
# 10 cycles received at: 2024-03-12 11:35:40.809000
#
# 10 cycles received at: 2024-03-12 11:35:41.009001
#
# 10 cycles received at: 2024-03-12 11:35:41.209000
#
# 10 cycles received at: 2024-03-12 11:35:41.409000
#
# 10 cycles received at: 2024-03-12 11:35:41.608999
#
# 10 cycles received at: 2024-03-12 11:35:41.809000
#
# 10 cycles received at: 2024-03-12 11:35:42.009001
#
# 10 cycles received at: 2024-03-12 11:35:42.209000
#
# 10 cycles received at: 2024-03-12 11:35:42.409000
#
# 10 cycles received at: 2024-03-12 11:35:42.608999
#
# 10 cycles received at: 2024-03-12 11:35:42.809000
#
# 10 cycles received at: 2024-03-12 11:35:43.009001
#
# 10 cycles received at: 2024-03-12 11:35:43.209000
#
# 10 cycles received at: 2024-03-12 11:35:43.409000
#
# 10 cycles received at: 2024-03-12 11:35:43.608999
#
# 10 cycles received at: 2024-03-12 11:35:43.809000
#
# 10 cycles received at: 2024-03-12 11:35:44.009001
#
# 10 cycles received at: 2024-03-12 11:35:44.209000
#
# 10 cycles received at: 2024-03-12 11:35:44.409000
#
# 10 cycles received at: 2024-03-12 11:35:44.608999
#
# 10 cycles received at: 2024-03-12 11:35:44.809000
#
# 10 cycles received at: 2024-03-12 11:35:45.009001
#
# 10 cycles received at: 2024-03-12 11:35:45.209000
#
# 10 cycles received at: 2024-03-12 11:35:45.409000
#
# 10 cycles received at: 2024-03-12 11:35:45.608999
#
# 10 cycles received at: 2024-03-12 11:35:45.809000
#
# 10 cycles received at: 2024-03-12 11:35:46.009001
#
# 10 cycles received at: 2024-03-12 11:35:46.209000
#
# 10 cycles received at: 2024-03-12 11:35:46.409000
#
# 10 cycles received at: 2024-03-12 11:35:46.608999
#
# 10 cycles received at: 2024-03-12 11:35:46.809000
#
# 10 cycles received at: 2024-03-12 11:35:47.009001
#
# 10 cycles received at: 2024-03-12 11:35:47.209000
#
# 10 cycles received at: 2024-03-12 11:35:47.409000
#
# 10 cycles received at: 2024-03-12 11:35:47.608999
#
# 10 cycles received at: 2024-03-12 11:35:47.809000
#
# 10 cycles received at: 2024-03-12 11:35:48.009001
#
# 10 cycles received at: 2024-03-12 11:35:48.209000
#
# 10 cycles received at: 2024-03-12 11:35:48.409000
#
# 10 cycles received at: 2024-03-12 11:35:48.608999
#
# 10 cycles received at: 2024-03-12 11:35:48.809000
#
# 10 cycles received at: 2024-03-12 11:35:49.009001
#
# 10 cycles received at: 2024-03-12 11:35:49.209000
#
# 10 cycles received at: 2024-03-12 11:35:49.409000
#
# 10 cycles received at: 2024-03-12 11:35:49.608999
#
# 10 cycles received at: 2024-03-12 11:35:49.809000
#
# 10 cycles received at: 2024-03-12 11:35:50.009001
#
# 10 cycles received at: 2024-03-12 11:35:50.209000
#
# 10 cycles received at: 2024-03-12 11:35:50.409000
#
# 10 cycles received at: 2024-03-12 11:35:50.608999
#
# 10 cycles received at: 2024-03-12 11:35:50.809000
#
# 10 cycles received at: 2024-03-12 11:35:51.009001
#
# 10 cycles received at: 2024-03-12 11:35:51.209000
#
# 10 cycles received at: 2024-03-12 11:35:51.409000
#
# 10 cycles received at: 2024-03-12 11:35:51.608999
#
# 10 cycles received at: 2024-03-12 11:35:51.809000
#
# 10 cycles received at: 2024-03-12 11:35:52.009001
#
# 10 cycles received at: 2024-03-12 11:35:52.209000
#
# 10 cycles received at: 2024-03-12 11:35:52.409000
#
# 10 cycles received at: 2024-03-12 11:35:52.608999
#
# 10 cycles received at: 2024-03-12 11:35:52.809000
#
# 10 cycles received at: 2024-03-12 11:35:53.009001
#
# 10 cycles received at: 2024-03-12 11:35:53.209000
#
# 10 cycles received at: 2024-03-12 11:35:53.409000
#
# 10 cycles received at: 2024-03-12 11:35:53.608999
#
# 10 cycles received at: 2024-03-12 11:35:53.809000
#
# 10 cycles received at: 2024-03-12 11:35:54.009001
#
# 10 cycles received at: 2024-03-12 11:35:54.209000
#
# 10 cycles received at: 2024-03-12 11:35:54.409000
#
# 10 cycles received at: 2024-03-12 11:35:54.608999
#
# 10 cycles received at: 2024-03-12 11:35:54.809000
#
# 10 cycles received at: 2024-03-12 11:35:55.009001
#
# 10 cycles received at: 2024-03-12 11:35:55.209000
#
# 10 cycles received at: 2024-03-12 11:35:55.409000
#
# 10 cycles received at: 2024-03-12 11:35:55.608999
#
# 10 cycles received at: 2024-03-12 11:35:55.809000
#
# 10 cycles received at: 2024-03-12 11:35:56.009001
#
# 10 cycles received at: 2024-03-12 11:35:56.209000
#
# 10 cycles received at: 2024-03-12 11:35:56.409000
#
# 10 cycles received at: 2024-03-12 11:35:56.608999
#
# 10 cycles received at: 2024-03-12 11:35:56.809000
#
# 10 cycles received at: 2024-03-12 11:35:57.009001
#
# 10 cycles received at: 2024-03-12 11:35:57.209000
#
# 10 cycles received at: 2024-03-12 11:35:57.409000
#
# 10 cycles received at: 2024-03-12 11:35:57.608999
#
# 10 cycles received at: 2024-03-12 11:35:57.809000
#
# 10 cycles received at: 2024-03-12 11:35:58.009001
#
# 10 cycles received at: 2024-03-12 11:35:58.209000
#
# 10 cycles received at: 2024-03-12 11:35:58.409000
#
# 10 cycles received at: 2024-03-12 11:35:58.608999
#
# 10 cycles received at: 2024-03-12 11:35:58.809000
#
# 10 cycles received at: 2024-03-12 11:35:59.009001
#
# 10 cycles received at: 2024-03-12 11:35:59.209000
#
# 10 cycles received at: 2024-03-12 11:35:59.409000
#
# 10 cycles received at: 2024-03-12 11:35:59.608999
#
# 10 cycles received at: 2024-03-12 11:35:59.809000
#
# 10 cycles received at: 2024-03-12 11:36:00.009001
#
# 10 cycles received at: 2024-03-12 11:36:00.209000
#
# 10 cycles received at: 2024-03-12 11:36:00.409000
#
# 10 cycles received at: 2024-03-12 11:36:00.608999
#
# 10 cycles received at: 2024-03-12 11:36:00.809000
#
# 10 cycles received at: 2024-03-12 11:36:01.009001
#
# 10 cycles received at: 2024-03-12 11:36:01.209000
#
# 10 cycles received at: 2024-03-12 11:36:01.409000
#
# 10 cycles received at: 2024-03-12 11:36:01.608999
#
# 10 cycles received at: 2024-03-12 11:36:01.809000
#
# 10 cycles received at: 2024-03-12 11:36:02.009001
#
# 10 cycles received at: 2024-03-12 11:36:02.209000
#
# 10 cycles received at: 2024-03-12 11:36:02.409000
#
# 10 cycles received at: 2024-03-12 11:36:02.608999
#
# 10 cycles received at: 2024-03-12 11:36:02.809000
#
# 10 cycles received at: 2024-03-12 11:36:03.009001
#
# 10 cycles received at: 2024-03-12 11:36:03.209000
#
# 10 cycles received at: 2024-03-12 11:36:03.409000
#
# 10 cycles received at: 2024-03-12 11:36:03.608999
#
# 10 cycles received at: 2024-03-12 11:36:03.809000
#
# 10 cycles received at: 2024-03-12 11:36:04.009001
#
# 10 cycles received at: 2024-03-12 11:36:04.209000
#
# 10 cycles received at: 2024-03-12 11:36:04.409000
# Swell Start: 2024-03-12 11:36:04.489000
#
# 10 cycles received at: 2024-03-12 11:36:04.608999
#
# 10 cycles received at: 2024-03-12 11:36:04.809000
#
# 10 cycles received at: 2024-03-12 11:36:05.009001
#
# 10 cycles received at: 2024-03-12 11:36:05.209000
#
# 10 cycles received at: 2024-03-12 11:36:05.409000
#
# 10 cycles received at: 2024-03-12 11:36:05.608999
#
# 10 cycles received at: 2024-03-12 11:36:05.809000
#
# 10 cycles received at: 2024-03-12 11:36:06.009001
#
# 10 cycles received at: 2024-03-12 11:36:06.209000
#
# 10 cycles received at: 2024-03-12 11:36:06.409000
#
# 10 cycles received at: 2024-03-12 11:36:06.608999
#
# 10 cycles received at: 2024-03-12 11:36:06.809000
#
# 10 cycles received at: 2024-03-12 11:36:07.009001
#
# 10 cycles received at: 2024-03-12 11:36:07.209000
#
# 10 cycles received at: 2024-03-12 11:36:07.409000
#
# 10 cycles received at: 2024-03-12 11:36:07.608999
#
# 10 cycles received at: 2024-03-12 11:36:07.809000
#
# 10 cycles received at: 2024-03-12 11:36:08.009001
#
# 10 cycles received at: 2024-03-12 11:36:08.209000
#
# 10 cycles received at: 2024-03-12 11:36:08.409000
#
# 10 cycles received at: 2024-03-12 11:36:08.608999
#
# 10 cycles received at: 2024-03-12 11:36:08.809000
#
# 10 cycles received at: 2024-03-12 11:36:09.009001
#
# 10 cycles received at: 2024-03-12 11:36:09.209000
#
# 10 cycles received at: 2024-03-12 11:36:09.409000
#
# 10 cycles received at: 2024-03-12 11:36:09.608999
#
# 10 cycles received at: 2024-03-12 11:36:09.809000
#
# 10 cycles received at: 2024-03-12 11:36:10.009001
#
# 10 cycles received at: 2024-03-12 11:36:10.209000
#
# 10 cycles received at: 2024-03-12 11:36:10.409000
#
# 10 cycles received at: 2024-03-12 11:36:10.608999
#
# 10 cycles received at: 2024-03-12 11:36:10.809000
#
# 10 cycles received at: 2024-03-12 11:36:11.009001
#
# 10 cycles received at: 2024-03-12 11:36:11.209000
#
# 10 cycles received at: 2024-03-12 11:36:11.409000
#
# 10 cycles received at: 2024-03-12 11:36:11.608999
#
# 10 cycles received at: 2024-03-12 11:36:11.809000
#
# 10 cycles received at: 2024-03-12 11:36:12.009001
#
# 10 cycles received at: 2024-03-12 11:36:12.209000
#
# 10 cycles received at: 2024-03-12 11:36:12.409000
#
# 10 cycles received at: 2024-03-12 11:36:12.608999
#
# 10 cycles received at: 2024-03-12 11:36:12.809000
#
# 10 cycles received at: 2024-03-12 11:36:13.009001
#
# 10 cycles received at: 2024-03-12 11:36:13.209000
#
# 10 cycles received at: 2024-03-12 11:36:13.409000
#
# 10 cycles received at: 2024-03-12 11:36:13.608999
#
# 10 cycles received at: 2024-03-12 11:36:13.809000
#
# 10 cycles received at: 2024-03-12 11:36:14.009001
#
# 10 cycles received at: 2024-03-12 11:36:14.209000
#
# 10 cycles received at: 2024-03-12 11:36:14.409000
#
# 10 cycles received at: 2024-03-12 11:36:14.608999
#
# 10 cycles received at: 2024-03-12 11:36:14.809000
#
# 10 cycles received at: 2024-03-12 11:36:15.009001
#
# 10 cycles received at: 2024-03-12 11:36:15.209000
#
# 10 cycles received at: 2024-03-12 11:36:15.409000
#
# 10 cycles received at: 2024-03-12 11:36:15.608999
#
# 10 cycles received at: 2024-03-12 11:36:15.809000
#
# 10 cycles received at: 2024-03-12 11:36:16.009001
#
# 10 cycles received at: 2024-03-12 11:36:16.209000
#
# 10 cycles received at: 2024-03-12 11:36:16.409000
#
# 10 cycles received at: 2024-03-12 11:36:16.608999
#
# 10 cycles received at: 2024-03-12 11:36:16.809000
#
# 10 cycles received at: 2024-03-12 11:36:17.009001
#
# 10 cycles received at: 2024-03-12 11:36:17.209000
#
# 10 cycles received at: 2024-03-12 11:36:17.409000
#
# 10 cycles received at: 2024-03-12 11:36:17.608999
#
# 10 cycles received at: 2024-03-12 11:36:17.809000
#
# 10 cycles received at: 2024-03-12 11:36:18.009001
#
# 10 cycles received at: 2024-03-12 11:36:18.209000
#
# 10 cycles received at: 2024-03-12 11:36:18.409000
#
# 10 cycles received at: 2024-03-12 11:36:18.608999
#
# 10 cycles received at: 2024-03-12 11:36:18.809000
#
# 10 cycles received at: 2024-03-12 11:36:19.009001
#
# 10 cycles received at: 2024-03-12 11:36:19.209000
#
# 10 cycles received at: 2024-03-12 11:36:19.409000
#
# 10 cycles received at: 2024-03-12 11:36:19.608999
#
# 10 cycles received at: 2024-03-12 11:36:19.809000
#
# 10 cycles received at: 2024-03-12 11:36:20.009001
#
# 10 cycles received at: 2024-03-12 11:36:20.209000
#
# 10 cycles received at: 2024-03-12 11:36:20.409000
#
# 10 cycles received at: 2024-03-12 11:36:20.608999
#
# 10 cycles received at: 2024-03-12 11:36:20.809000
#
# 10 cycles received at: 2024-03-12 11:36:21.009001
#
# 10 cycles received at: 2024-03-12 11:36:21.209000
#
# 10 cycles received at: 2024-03-12 11:36:21.409000
#
# 10 cycles received at: 2024-03-12 11:36:21.608999
#
# 10 cycles received at: 2024-03-12 11:36:21.809000
#
# 10 cycles received at: 2024-03-12 11:36:22.009001
#
# 10 cycles received at: 2024-03-12 11:36:22.209000
#
# 10 cycles received at: 2024-03-12 11:36:22.409000
#
# 10 cycles received at: 2024-03-12 11:36:22.608999
#
# 10 cycles received at: 2024-03-12 11:36:22.809000
#
# 10 cycles received at: 2024-03-12 11:36:23.009001
#
# 10 cycles received at: 2024-03-12 11:36:23.209000
#
# 10 cycles received at: 2024-03-12 11:36:23.409000
#
# 10 cycles received at: 2024-03-12 11:36:23.608999
#
# 10 cycles received at: 2024-03-12 11:36:23.809000
#
# 10 cycles received at: 2024-03-12 11:36:24.009001
#
# 10 cycles received at: 2024-03-12 11:36:24.209000
#
# 10 cycles received at: 2024-03-12 11:36:24.409000
#
# 10 cycles received at: 2024-03-12 11:36:24.608999
#
# 10 cycles received at: 2024-03-12 11:36:24.809000
#
# 10 cycles received at: 2024-03-12 11:36:25.009001
#
# 10 cycles received at: 2024-03-12 11:36:25.209000
#
# 10 cycles received at: 2024-03-12 11:36:25.409000
#
# 10 cycles received at: 2024-03-12 11:36:25.608999
#
# 10 cycles received at: 2024-03-12 11:36:25.809000
#
# 10 cycles received at: 2024-03-12 11:36:26.009001
#
# 10 cycles received at: 2024-03-12 11:36:26.209000
#
# 10 cycles received at: 2024-03-12 11:36:26.409000
#
# 10 cycles received at: 2024-03-12 11:36:26.608999
#
# 10 cycles received at: 2024-03-12 11:36:26.809000
#
# 10 cycles received at: 2024-03-12 11:36:27.009001
#
# 10 cycles received at: 2024-03-12 11:36:27.209000
#
# 10 cycles received at: 2024-03-12 11:36:27.409000
#
# 10 cycles received at: 2024-03-12 11:36:27.608999
#
# 10 cycles received at: 2024-03-12 11:36:27.809000
#
# 10 cycles received at: 2024-03-12 11:36:28.009001
#
# 10 cycles received at: 2024-03-12 11:36:28.209000
#
# 10 cycles received at: 2024-03-12 11:36:28.409000
#
# 10 cycles received at: 2024-03-12 11:36:28.608999
#
# 10 cycles received at: 2024-03-12 11:36:28.809000
#
# 10 cycles received at: 2024-03-12 11:36:29.009001
#
# 10 cycles received at: 2024-03-12 11:36:29.209000
#
# 10 cycles received at: 2024-03-12 11:36:29.409000
#
# 10 cycles received at: 2024-03-12 11:36:29.608999
#
# 10 cycles received at: 2024-03-12 11:36:29.809000
#
# 10 cycles received at: 2024-03-12 11:36:30.009001
#
# 10 cycles received at: 2024-03-12 11:36:30.209000
#
# 10 cycles received at: 2024-03-12 11:36:30.409000
#
# 10 cycles received at: 2024-03-12 11:36:30.608999
#
# 10 cycles received at: 2024-03-12 11:36:30.809000
#
# 10 cycles received at: 2024-03-12 11:36:31.009001
#
# 10 cycles received at: 2024-03-12 11:36:31.209000
#
# 10 cycles received at: 2024-03-12 11:36:31.409000
#
# 10 cycles received at: 2024-03-12 11:36:31.608999
#
# 10 cycles received at: 2024-03-12 11:36:31.809000
#
# 10 cycles received at: 2024-03-12 11:36:32.009001
#
# 10 cycles received at: 2024-03-12 11:36:32.209000
#
# 10 cycles received at: 2024-03-12 11:36:32.409000
#
# 10 cycles received at: 2024-03-12 11:36:32.608999
#
# 10 cycles received at: 2024-03-12 11:36:32.809000
#
# 10 cycles received at: 2024-03-12 11:36:33.009001
#
# 10 cycles received at: 2024-03-12 11:36:33.209000
#
# 10 cycles received at: 2024-03-12 11:36:33.409000
#
# 10 cycles received at: 2024-03-12 11:36:33.608999
# Swell End: 2024-03-12 11:36:33.698999
#
# *********************************************************************************
# Swell Duration: 0:00:29.209999
# Retained Voltage: 272.30127387645433
# Swell Type: Temporary
# *********************************************************************************
#
# 10 cycles received at: 2024-03-12 11:36:33.809000
#
# 10 cycles received at: 2024-03-12 11:36:34.009001
#
# 10 cycles received at: 2024-03-12 11:36:34.209000
#
# 10 cycles received at: 2024-03-12 11:36:34.409000
#
# 10 cycles received at: 2024-03-12 11:36:34.608999
#
# 10 cycles received at: 2024-03-12 11:36:34.809000
#
# 10 cycles received at: 2024-03-12 11:36:35.009001
#
# 10 cycles received at: 2024-03-12 11:36:35.209000
#
# 10 cycles received at: 2024-03-12 11:36:35.409000
#
# 10 cycles received at: 2024-03-12 11:36:35.608999
#
# 10 cycles received at: 2024-03-12 11:36:35.809000
#
# 10 cycles received at: 2024-03-12 11:36:36.009001
#
# 10 cycles received at: 2024-03-12 11:36:36.209000
#
# 10 cycles received at: 2024-03-12 11:36:36.409000
#
# 10 cycles received at: 2024-03-12 11:36:36.608999
#
# 10 cycles received at: 2024-03-12 11:36:36.809000
#
# 10 cycles received at: 2024-03-12 11:36:37.009001
#
# 10 cycles received at: 2024-03-12 11:36:37.209000
#
# 10 cycles received at: 2024-03-12 11:36:37.409000
#
# 10 cycles received at: 2024-03-12 11:36:37.608999
#
# 10 cycles received at: 2024-03-12 11:36:37.809000
#
# 10 cycles received at: 2024-03-12 11:36:38.009001
#
# 10 cycles received at: 2024-03-12 11:36:38.209000
#
# 10 cycles received at: 2024-03-12 11:36:38.409000
#
# 10 cycles received at: 2024-03-12 11:36:38.608999
#
# 10 cycles received at: 2024-03-12 11:36:38.809000
#
# 10 cycles received at: 2024-03-12 11:36:39.009001
#
# 10 cycles received at: 2024-03-12 11:36:39.209000
#
# 10 cycles received at: 2024-03-12 11:36:39.409000
#
# 10 cycles received at: 2024-03-12 11:36:39.608999
#
# 10 cycles received at: 2024-03-12 11:36:39.809000
#
# 10 cycles received at: 2024-03-12 11:36:40.009001
#
# 10 cycles received at: 2024-03-12 11:36:40.209000
#
# 10 cycles received at: 2024-03-12 11:36:40.409000
#
# 10 cycles received at: 2024-03-12 11:36:40.608999
#
# 10 cycles received at: 2024-03-12 11:36:40.809000
#
# 10 cycles received at: 2024-03-12 11:36:41.009001
#
# 10 cycles received at: 2024-03-12 11:36:41.209000
#
# 10 cycles received at: 2024-03-12 11:36:41.409000
#
# 10 cycles received at: 2024-03-12 11:36:41.608999
#
# 10 cycles received at: 2024-03-12 11:36:41.809000
#
# 10 cycles received at: 2024-03-12 11:36:42.009001
#
# 10 cycles received at: 2024-03-12 11:36:42.209000
#
# 10 cycles received at: 2024-03-12 11:36:42.409000
#
# 10 cycles received at: 2024-03-12 11:36:42.608999
#
# 10 cycles received at: 2024-03-12 11:36:42.809000
#
# 10 cycles received at: 2024-03-12 11:36:43.009001
#
# 10 cycles received at: 2024-03-12 11:36:43.209000
#
# 10 cycles received at: 2024-03-12 11:36:43.409000
#
# 10 cycles received at: 2024-03-12 11:36:43.608999
#
# 10 cycles received at: 2024-03-12 11:36:43.809000
#
# 10 cycles received at: 2024-03-12 11:36:44.009001
#
# 10 cycles received at: 2024-03-12 11:36:44.209000
#
# 10 cycles received at: 2024-03-12 11:36:44.409000
#
# 10 cycles received at: 2024-03-12 11:36:44.608999
#
# 10 cycles received at: 2024-03-12 11:36:44.809000
#
# 10 cycles received at: 2024-03-12 11:36:45.009001
#
# 10 cycles received at: 2024-03-12 11:36:45.209000
#
# 10 cycles received at: 2024-03-12 11:36:45.409000
#
# 10 cycles received at: 2024-03-12 11:36:45.608999
#
# 10 cycles received at: 2024-03-12 11:36:45.809000
#
# 10 cycles received at: 2024-03-12 11:36:46.009001
#
# 10 cycles received at: 2024-03-12 11:36:46.209000
#
# 10 cycles received at: 2024-03-12 11:36:46.409000
#
# 10 cycles received at: 2024-03-12 11:36:46.608999
#
# 10 cycles received at: 2024-03-12 11:36:46.809000
#
# 10 cycles received at: 2024-03-12 11:36:47.009001
#
# 10 cycles received at: 2024-03-12 11:36:47.209000
#
# 10 cycles received at: 2024-03-12 11:36:47.409000
#
# 10 cycles received at: 2024-03-12 11:36:47.608999
#
# 10 cycles received at: 2024-03-12 11:36:47.809000
#
# 10 cycles received at: 2024-03-12 11:36:48.009001
#
# 10 cycles received at: 2024-03-12 11:36:48.209000
#
# 10 cycles received at: 2024-03-12 11:36:48.409000
#
# 10 cycles received at: 2024-03-12 11:36:48.608999
#
# 10 cycles received at: 2024-03-12 11:36:48.809000
#
# 10 cycles received at: 2024-03-12 11:36:49.009001
#
# 10 cycles received at: 2024-03-12 11:36:49.209000
#
# 10 cycles received at: 2024-03-12 11:36:49.409000
#
# 10 cycles received at: 2024-03-12 11:36:49.608999
#
# 10 cycles received at: 2024-03-12 11:36:49.809000
#
# 10 cycles received at: 2024-03-12 11:36:50.009001
#
# 10 cycles received at: 2024-03-12 11:36:50.209000
#
# 10 cycles received at: 2024-03-12 11:36:50.409000
#
# 10 cycles received at: 2024-03-12 11:36:50.608999
#
# 10 cycles received at: 2024-03-12 11:36:50.809000
#
# 10 cycles received at: 2024-03-12 11:36:51.009001
#
# 10 cycles received at: 2024-03-12 11:36:51.209000
#
# 10 cycles received at: 2024-03-12 11:36:51.409000
#
# 10 cycles received at: 2024-03-12 11:36:51.608999
#
# 10 cycles received at: 2024-03-12 11:36:51.809000
#
# 10 cycles received at: 2024-03-12 11:36:52.009001
#
# 10 cycles received at: 2024-03-12 11:36:52.209000
#
# 10 cycles received at: 2024-03-12 11:36:52.409000
#
# 10 cycles received at: 2024-03-12 11:36:52.608999
#
# 10 cycles received at: 2024-03-12 11:36:52.809000
#
# 10 cycles received at: 2024-03-12 11:36:53.009001
#
# 10 cycles received at: 2024-03-12 11:36:53.209000
#
# 10 cycles received at: 2024-03-12 11:36:53.409000
#
# 10 cycles received at: 2024-03-12 11:36:53.608999
#
# 10 cycles received at: 2024-03-12 11:36:53.809000
#
# 10 cycles received at: 2024-03-12 11:36:54.009001
#
# 10 cycles received at: 2024-03-12 11:36:54.209000
#
# 10 cycles received at: 2024-03-12 11:36:54.409000
#
# 10 cycles received at: 2024-03-12 11:36:54.608999
#
# 10 cycles received at: 2024-03-12 11:36:54.809000
#
# 10 cycles received at: 2024-03-12 11:36:55.009001
#
# 10 cycles received at: 2024-03-12 11:36:55.209000
#
# 10 cycles received at: 2024-03-12 11:36:55.409000
#
# 10 cycles received at: 2024-03-12 11:36:55.608999
#
# 10 cycles received at: 2024-03-12 11:36:55.809000
#
# 10 cycles received at: 2024-03-12 11:36:56.009001
#
# 10 cycles received at: 2024-03-12 11:36:56.209000
#
# 10 cycles received at: 2024-03-12 11:36:56.409000
#
# 10 cycles received at: 2024-03-12 11:36:56.608999
#
# 10 cycles received at: 2024-03-12 11:36:56.809000
#
# 10 cycles received at: 2024-03-12 11:36:57.009001
#
# 10 cycles received at: 2024-03-12 11:36:57.209000
#
# 10 cycles received at: 2024-03-12 11:36:57.409000
#
# 10 cycles received at: 2024-03-12 11:36:57.608999
#
# 10 cycles received at: 2024-03-12 11:36:57.809000
#
# 10 cycles received at: 2024-03-12 11:36:58.009001
#
# 10 cycles received at: 2024-03-12 11:36:58.209000
#
# 10 cycles received at: 2024-03-12 11:36:58.409000
#
# 10 cycles received at: 2024-03-12 11:36:58.608999
#
# 10 cycles received at: 2024-03-12 11:36:58.809000
#
# 10 cycles received at: 2024-03-12 11:36:59.009001
#
# 10 cycles received at: 2024-03-12 11:36:59.209000
#
# 10 cycles received at: 2024-03-12 11:36:59.409000
#
# 10 cycles received at: 2024-03-12 11:36:59.608999
#
# 10 cycles received at: 2024-03-12 11:36:59.809000
#
# 10 cycles received at: 2024-03-12 11:37:00.009001
#
# 10 cycles received at: 2024-03-12 11:37:00.209000
#
# 10 cycles received at: 2024-03-12 11:37:00.409000
#
# 10 cycles received at: 2024-03-12 11:37:00.608999
#
# 10 cycles received at: 2024-03-12 11:37:00.809000
#
# 10 cycles received at: 2024-03-12 11:37:01.009001
#
# 10 cycles received at: 2024-03-12 11:37:01.209000
#
# 10 cycles received at: 2024-03-12 11:37:01.409000
#
# 10 cycles received at: 2024-03-12 11:37:01.608999
#
# 10 cycles received at: 2024-03-12 11:37:01.809000
#
# 10 cycles received at: 2024-03-12 11:37:02.009001
#
# 10 cycles received at: 2024-03-12 11:37:02.209000
#
# 10 cycles received at: 2024-03-12 11:37:02.409000
#
# 10 cycles received at: 2024-03-12 11:37:02.608999
#
# 10 cycles received at: 2024-03-12 11:37:02.809000
#
# 10 cycles received at: 2024-03-12 11:37:03.009001
#
# 10 cycles received at: 2024-03-12 11:37:03.209000
#
# 10 cycles received at: 2024-03-12 11:37:03.409000
#
# 10 cycles received at: 2024-03-12 11:37:03.608999
#
# 10 cycles received at: 2024-03-12 11:37:03.809000
#
# 10 cycles received at: 2024-03-12 11:37:04.009001
#
# 10 cycles received at: 2024-03-12 11:37:04.209000
#
# 10 cycles received at: 2024-03-12 11:37:04.409000
#
# 10 cycles received at: 2024-03-12 11:37:04.608999
#
# 10 cycles received at: 2024-03-12 11:37:04.809000
#
# 10 cycles received at: 2024-03-12 11:37:05.009001
#
# 10 cycles received at: 2024-03-12 11:37:05.209000
#
# 10 cycles received at: 2024-03-12 11:37:05.409000
#
# 10 cycles received at: 2024-03-12 11:37:05.608999
#
# 10 cycles received at: 2024-03-12 11:37:05.809000
#
# 10 cycles received at: 2024-03-12 11:37:06.009001
#
# 10 cycles received at: 2024-03-12 11:37:06.209000
#
# 10 cycles received at: 2024-03-12 11:37:06.409000
#
# 10 cycles received at: 2024-03-12 11:37:06.608999
#
# 10 cycles received at: 2024-03-12 11:37:06.809000
#
# 10 cycles received at: 2024-03-12 11:37:07.009001
#
# 10 cycles received at: 2024-03-12 11:37:07.209000
#
# 10 cycles received at: 2024-03-12 11:37:07.409000
#
# 10 cycles received at: 2024-03-12 11:37:07.608999
#
# 10 cycles received at: 2024-03-12 11:37:07.809000
#
# 10 cycles received at: 2024-03-12 11:37:08.009001
#
# 10 cycles received at: 2024-03-12 11:37:08.209000
#
# 10 cycles received at: 2024-03-12 11:37:08.409000
#
# 10 cycles received at: 2024-03-12 11:37:08.608999
#
# 10 cycles received at: 2024-03-12 11:37:08.809000
#
# 10 cycles received at: 2024-03-12 11:37:09.009001
#
# 10 cycles received at: 2024-03-12 11:37:09.209000
#
# 10 cycles received at: 2024-03-12 11:37:09.409000
#
# 10 cycles received at: 2024-03-12 11:37:09.608999
#
# 10 cycles received at: 2024-03-12 11:37:09.809000
#
# 10 cycles received at: 2024-03-12 11:37:10.009001
#
# 10 cycles received at: 2024-03-12 11:37:10.209000
#
# 10 cycles received at: 2024-03-12 11:37:10.409000
#
# 10 cycles received at: 2024-03-12 11:37:10.608999
#
# 10 cycles received at: 2024-03-12 11:37:10.809000
#
# 10 cycles received at: 2024-03-12 11:37:11.009001
#
# 10 cycles received at: 2024-03-12 11:37:11.209000
#
# 10 cycles received at: 2024-03-12 11:37:11.409000
#
# 10 cycles received at: 2024-03-12 11:37:11.608999
#
# 10 cycles received at: 2024-03-12 11:37:11.809000
#
# 10 cycles received at: 2024-03-12 11:37:12.009001
#
# 10 cycles received at: 2024-03-12 11:37:12.209000
#
# 10 cycles received at: 2024-03-12 11:37:12.409000
#
# 10 cycles received at: 2024-03-12 11:37:12.608999
#
# 10 cycles received at: 2024-03-12 11:37:12.809000
#
# 10 cycles received at: 2024-03-12 11:37:13.009001
#
# 10 cycles received at: 2024-03-12 11:37:13.209000
#
# 10 cycles received at: 2024-03-12 11:37:13.409000
#
# 10 cycles received at: 2024-03-12 11:37:13.608999
#
# 10 cycles received at: 2024-03-12 11:37:13.809000
#
# 10 cycles received at: 2024-03-12 11:37:14.009001
#
# 10 cycles received at: 2024-03-12 11:37:14.209000
#
# 10 cycles received at: 2024-03-12 11:37:14.409000
#
# 10 cycles received at: 2024-03-12 11:37:14.608999
#
# 10 cycles received at: 2024-03-12 11:37:14.809000
#
# 10 cycles received at: 2024-03-12 11:37:15.009001
#
# 10 cycles received at: 2024-03-12 11:37:15.209000
#
# 10 cycles received at: 2024-03-12 11:37:15.409000
#
# 10 cycles received at: 2024-03-12 11:37:15.608999
#
# 10 cycles received at: 2024-03-12 11:37:15.809000
#
# 10 cycles received at: 2024-03-12 11:37:16.009001
#
# 10 cycles received at: 2024-03-12 11:37:16.209000
#
# 10 cycles received at: 2024-03-12 11:37:16.409000
#
# 10 cycles received at: 2024-03-12 11:37:16.608999
#
# 10 cycles received at: 2024-03-12 11:37:16.809000
#
# 10 cycles received at: 2024-03-12 11:37:17.009001
#
# 10 cycles received at: 2024-03-12 11:37:17.209000
#
# 10 cycles received at: 2024-03-12 11:37:17.409000
#
# 10 cycles received at: 2024-03-12 11:37:17.608999
#
# 10 cycles received at: 2024-03-12 11:37:17.809000
#
# 10 cycles received at: 2024-03-12 11:37:18.009001
#
# 10 cycles received at: 2024-03-12 11:37:18.209000
#
# 10 cycles received at: 2024-03-12 11:37:18.409000
#
# 10 cycles received at: 2024-03-12 11:37:18.608999
#
# 10 cycles received at: 2024-03-12 11:37:18.809000
#
# 10 cycles received at: 2024-03-12 11:37:19.009001
#
# 10 cycles received at: 2024-03-12 11:37:19.209000
#
# 10 cycles received at: 2024-03-12 11:37:19.409000
#
# *********************************************************************************
# Prime Harmonic Variation
# Dominant Frequency: 55.55555555555556
# *********************************************************************************
#
# *********************************************************************************
# THD Threshold Violated
# THD: 110.91046185010237 %
# *********************************************************************************
