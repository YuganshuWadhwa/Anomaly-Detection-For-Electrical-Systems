# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import plotly.graph_objects as go

from scipy.fft import fft
from scipy.signal import butter,filtfilt

import time

# %matplotlib widget

# %%
def modifyTimestamps(df):

    df = df.dropna()
    df = df.drop(df.filter(regex='Name..').columns, axis=1)
    df = df.rename(columns={"Name": "Time"})

    return df


def LDAP_to_time(t_array):

    timestamp_array = []

    for timestamp in t_array:

        if type(timestamp) == pd._libs.tslibs.timestamps.Timestamp:
            timestamp_array.append(timestamp)

        else:
            value = datetime.datetime(1601, 1, 1) + datetime.timedelta(seconds=timestamp/10000000)
            timestamp_array.append(value)

    return np.asarray(timestamp_array)

# %%
def lowpass_filter(signal, cutoff, fs, order):

    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq

    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, signal)
    
    return y

# %%
def rms_variation(V_array, T_array, anomaly_meta_info):

    for i in np.arange(start=0, stop=len(V_array), step=200):

        start = i
        end = i + 400

        V_rms = np.sqrt(np.mean(np.square(V_array[start:end])))


        if (V_rms >= 1.1 * anomaly_meta_info['voltage_threshold']):

            # swell start
            if (anomaly_meta_info['swell_start'] == None) and (anomaly_meta_info['swell_end'] == None):
                anomaly_meta_info['swell_start'] = T_array[i]
                print(f"Swell Start: {anomaly_meta_info['swell_start']}")


            if (V_rms >= anomaly_meta_info['max_swell_value']):
                anomaly_meta_info['max_swell_value'] = V_rms



        if (V_rms < 1.1 * anomaly_meta_info['voltage_threshold']) and (V_rms >= 0.9 * anomaly_meta_info['voltage_threshold']):

            # sag end
            if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_end'] = T_array[i]
                print(f"Sag End: {anomaly_meta_info['sag_end']}")


            # swell end
            if (anomaly_meta_info['swell_start'] != None) and (anomaly_meta_info['swell_end'] == None):
                anomaly_meta_info['swell_end'] = T_array[i]
                print(f"Swell End: {anomaly_meta_info['swell_end']}")


                
        if (V_rms < 0.9 * anomaly_meta_info['voltage_threshold']) and (V_rms >= 0.1 * anomaly_meta_info['voltage_threshold']):

            # sag start
            if (anomaly_meta_info['sag_start'] == None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_start'] = T_array[i]
                print(f"Sag Start: {anomaly_meta_info['sag_start']}")


            if (V_rms <= anomaly_meta_info['min_sag_value']):
                anomaly_meta_info['min_sag_value'] = V_rms


            # interruption end
            if (anomaly_meta_info['interruption_start'] != None) and (anomaly_meta_info['interruption_end'] == None):
                anomaly_meta_info['interruption_end'] = T_array[i]
                print(f"Interruption End: {anomaly_meta_info['interruption_end']}")


        
        if (V_rms < 0.1 * anomaly_meta_info['voltage_threshold']):

            # sag end
            if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_end'] = T_array[i]
                print(f"Sag End: {anomaly_meta_info['sag_end']}")


            # interruption start
            if (anomaly_meta_info['interruption_start'] == None) and (anomaly_meta_info['interruption_end'] == None):
                anomaly_meta_info['interruption_start'] = T_array[i]
                print(f"Interruption Start: {anomaly_meta_info['interruption_start']}")



        # reporting detected sag
        if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] != None):
            sag_duration = anomaly_meta_info['sag_end'] - anomaly_meta_info['sag_start']

            print("\n*********************************************************************************")
            print(f"Sag Duration: {sag_duration}")
            print(f"Retained Voltage: {anomaly_meta_info['min_sag_value']}")

            if (sag_duration <= datetime.timedelta(seconds=0.599853)): print(f"Sag Type: Instantaneous")
            elif (sag_duration > datetime.timedelta(seconds=0.599853)) and (sag_duration <= datetime.timedelta(seconds=3)): print(f"Sag Type: Momentary")
            elif (sag_duration > datetime.timedelta(seconds=3)) and (sag_duration <= datetime.timedelta(minutes=1)): print(f"Sag Type: Temporary")
            elif (sag_duration > datetime.timedelta(minutes=1)): print(f"Sag Type: Long Term Undervoltage")
            print("*********************************************************************************")

            anomaly_meta_info['sag_start'] = None
            anomaly_meta_info['sag_end'] = None
            anomaly_meta_info['min_sag_value'] = 1000000.



        # reporting detected swell
        if (anomaly_meta_info['swell_start'] != None) and (anomaly_meta_info['swell_end'] != None):
            swell_duration = anomaly_meta_info['swell_end'] - anomaly_meta_info['swell_start']

            print("\n*********************************************************************************")
            print(f"Swell Duration: {swell_duration}")
            print(f"Retained Voltage: {anomaly_meta_info['max_swell_value']}")

            if (swell_duration <= datetime.timedelta(seconds=0.599853)): print(f"Swell Type: Instantaneous")
            elif (swell_duration > datetime.timedelta(seconds=0.599853)) and (swell_duration <= datetime.timedelta(seconds=3)): print(f"Swell Type: Momentary")
            elif (swell_duration > datetime.timedelta(seconds=3)) and (swell_duration <= datetime.timedelta(minutes=1)): print(f"Swell Type: Temporary")
            elif (swell_duration > datetime.timedelta(minutes=1)): print(f"Swell Type: Long Term Overvoltage")
            print("*********************************************************************************")

            anomaly_meta_info['swell_start'] = None
            anomaly_meta_info['swell_end'] = None
            anomaly_meta_info['max_swell_value'] = 0.



        # reporting detected interruption
        if (anomaly_meta_info['interruption_start'] != None) and (anomaly_meta_info['interruption_end'] != None):
            interruption_duration = anomaly_meta_info['interruption_end'] - anomaly_meta_info['interruption_start']

            print("\n*********************************************************************************")
            print(f"Interruption Duration: {interruption_duration}")

            if (interruption_duration <= datetime.timedelta(seconds=3)): print(f"Interruption Type: Momentary")
            elif (interruption_duration > datetime.timedelta(seconds=3)) and (interruption_duration <= datetime.timedelta(minutes=1)): print(f"Interruption Type: Temporary")
            elif (interruption_duration > datetime.timedelta(minutes=1)): print(f"Interruption Type: Long Term Sustained Interruption")
            print("*********************************************************************************")

            anomaly_meta_info['interruption_start'] = None
            anomaly_meta_info['interruption_end'] = None



    return anomaly_meta_info

# %%
def thd_variation(signal, anomaly_meta_info, fs=20000):

    X = fft(signal)
    N = len(X)
    n = np.arange(N)
    T = N/fs


    freq = (n/T)[1:int(N/2)] 
    freq_amplitudes = np.abs(X)[1:int(N/2)]

    sorted_indices = np.argsort(-freq_amplitudes)

    dominant_freq = freq[sorted_indices[0]]
    other_freq = freq[sorted_indices[1:]]

    anomaly_meta_info['dominant_freq'] = dominant_freq


    sq_sum = np.sum(np.square(freq_amplitudes))

    sq_prime = np.square(np.max(freq_amplitudes))
    sq_harmonics = sq_sum - sq_prime

    thd = 100 * np.sqrt(sq_harmonics / sq_prime)

    anomaly_meta_info['thd'] = thd


    # # reporting detected prime harmonic variation
    # if (dominant_freq != anomaly_meta_info['required_freq']): 

    #     print("\n*********************************************************************************")
    #     print(f"Prime Harmonic Variation")
    #     print(f"Dominant Frequency: {anomaly_meta_info['dominant_freq']}")
    #     print("*********************************************************************************")

    
    # # reporting detected THD variation
    # if (thd > anomaly_meta_info['thd_threshold']): 
        
    #     print("\n*********************************************************************************")
    #     print(f"THD Threshold Violated")
    #     print(f"THD: {anomaly_meta_info['thd']} %")
    #     print("*********************************************************************************")


    return anomaly_meta_info

# %%
def anomaly_detection(V_array, I_array, T_array, anomaly_meta_info):

    print(f'\n10 cycles received at: {T_array[0]}')


    V1_filt = lowpass_filter(signal=V_array, cutoff=500, fs=20000, order=2)
    I1_filt = lowpass_filter(signal=I_array, cutoff=500, fs=20000, order=2)


    anomaly_meta_info = rms_variation(V_array=V1_filt, T_array=T_array, anomaly_meta_info=anomaly_meta_info)
    anomaly_meta_info = thd_variation(signal=V1_filt, anomaly_meta_info=anomaly_meta_info)


    return anomaly_meta_info

# %%
df = pd.read_csv('Power Anomalies Simulations Data/AD3_data/2024_03_12/01_Power Failure.csv', sep=';')
df = modifyTimestamps(df=df)

factor = 192.76315789473685

V1_complete = df['U_L1real'].iloc[:].to_numpy() * factor
I1_complete = df['I_L1real'].iloc[:].to_numpy()
T_complete = df['Time'].iloc[:].to_numpy()


anomaly_meta_info = {
    'voltage_threshold': 230.,

    'swell_start': None,
    'swell_end': None,
    'max_swell_value': 0.,

    'sag_start': None,
    'sag_end': None,
    'min_sag_value': 1000000.,

    'interruption_start': None,
    'interruption_end': None,

    'required_freq': 50.,
    'dominant_freq': None,

    'thd_threshold': 8.,
    'thd': None,
}

# %%
for i in np.arange(start=0, stop=len(V1_complete), step=4000):

    start = i
    end = start + 4000

    V1 = V1_complete[start:end]
    I1 = I1_complete[start:end]

    T1 = T_complete[start:end]
    T1 = LDAP_to_time(t_array=T1)

    if len(V1) >= 400:
        anomaly_meta_info = anomaly_detection(V_array=V1, I_array=I1, T_array=T1, anomaly_meta_info=anomaly_meta_info)

    # time.sleep(2)
# Out:
# 10 cycles received at: 2024-03-12 11:14:33.108999
#
# 10 cycles received at: 2024-03-12 11:14:33.309000
#
# 10 cycles received at: 2024-03-12 11:14:33.509001
#
# 10 cycles received at: 2024-03-12 11:14:33.709000
#
# 10 cycles received at: 2024-03-12 11:14:33.909000
#
# 10 cycles received at: 2024-03-12 11:14:34.108999
#
# 10 cycles received at: 2024-03-12 11:14:34.309000
#
# 10 cycles received at: 2024-03-12 11:14:34.509001
#
# 10 cycles received at: 2024-03-12 11:14:34.709000
#
# 10 cycles received at: 2024-03-12 11:14:34.909000
#
# 10 cycles received at: 2024-03-12 11:14:35.108999
#
# 10 cycles received at: 2024-03-12 11:14:35.309000
#
# 10 cycles received at: 2024-03-12 11:14:35.509001
#
# 10 cycles received at: 2024-03-12 11:14:35.709000
#
# 10 cycles received at: 2024-03-12 11:14:35.909000
#
# 10 cycles received at: 2024-03-12 11:14:36.108999
#
# 10 cycles received at: 2024-03-12 11:14:36.309000
#
# 10 cycles received at: 2024-03-12 11:14:36.509001
#
# 10 cycles received at: 2024-03-12 11:14:36.709000
#
# 10 cycles received at: 2024-03-12 11:14:36.909000
#
# 10 cycles received at: 2024-03-12 11:14:37.108999
#
# 10 cycles received at: 2024-03-12 11:14:37.309000
#
# 10 cycles received at: 2024-03-12 11:14:37.509001
#
# 10 cycles received at: 2024-03-12 11:14:37.709000
#
# 10 cycles received at: 2024-03-12 11:14:37.909000
#
# 10 cycles received at: 2024-03-12 11:14:38.108999
#
# 10 cycles received at: 2024-03-12 11:14:38.309000
#
# 10 cycles received at: 2024-03-12 11:14:38.509001
#
# 10 cycles received at: 2024-03-12 11:14:38.709000
#
# 10 cycles received at: 2024-03-12 11:14:38.909000
#
# 10 cycles received at: 2024-03-12 11:14:39.108999
#
# 10 cycles received at: 2024-03-12 11:14:39.309000
#
# 10 cycles received at: 2024-03-12 11:14:39.509001
#
# 10 cycles received at: 2024-03-12 11:14:39.709000
#
# 10 cycles received at: 2024-03-12 11:14:39.909000
#
# 10 cycles received at: 2024-03-12 11:14:40.108999
#
# 10 cycles received at: 2024-03-12 11:14:40.309000
#
# 10 cycles received at: 2024-03-12 11:14:40.509001
#
# 10 cycles received at: 2024-03-12 11:14:40.709000
#
# 10 cycles received at: 2024-03-12 11:14:40.909000
#
# 10 cycles received at: 2024-03-12 11:14:41.108999
#
# 10 cycles received at: 2024-03-12 11:14:41.309000
#
# 10 cycles received at: 2024-03-12 11:14:41.509001
#
# 10 cycles received at: 2024-03-12 11:14:41.709000
#
# 10 cycles received at: 2024-03-12 11:14:41.909000
#
# 10 cycles received at: 2024-03-12 11:14:42.108999
#
# 10 cycles received at: 2024-03-12 11:14:42.309000
#
# 10 cycles received at: 2024-03-12 11:14:42.509001
#
# 10 cycles received at: 2024-03-12 11:14:42.709000
#
# 10 cycles received at: 2024-03-12 11:14:42.909000
#
# 10 cycles received at: 2024-03-12 11:14:43.108999
#
# 10 cycles received at: 2024-03-12 11:14:43.309000
#
# 10 cycles received at: 2024-03-12 11:14:43.509001
#
# 10 cycles received at: 2024-03-12 11:14:43.709000
#
# 10 cycles received at: 2024-03-12 11:14:43.909000
#
# 10 cycles received at: 2024-03-12 11:14:44.108999
#
# 10 cycles received at: 2024-03-12 11:14:44.309000
#
# 10 cycles received at: 2024-03-12 11:14:44.509001
#
# 10 cycles received at: 2024-03-12 11:14:44.709000
#
# 10 cycles received at: 2024-03-12 11:14:44.909000
#
# 10 cycles received at: 2024-03-12 11:14:45.108999
#
# 10 cycles received at: 2024-03-12 11:14:45.309000
#
# 10 cycles received at: 2024-03-12 11:14:45.509001
#
# 10 cycles received at: 2024-03-12 11:14:45.709000
#
# 10 cycles received at: 2024-03-12 11:14:45.909000
#
# 10 cycles received at: 2024-03-12 11:14:46.108999
#
# 10 cycles received at: 2024-03-12 11:14:46.309000
#
# 10 cycles received at: 2024-03-12 11:14:46.509001
#
# 10 cycles received at: 2024-03-12 11:14:46.709000
#
# 10 cycles received at: 2024-03-12 11:14:46.909000
#
# 10 cycles received at: 2024-03-12 11:14:47.108999
#
# 10 cycles received at: 2024-03-12 11:14:47.309000
#
# 10 cycles received at: 2024-03-12 11:14:47.509001
#
# 10 cycles received at: 2024-03-12 11:14:47.709000
#
# 10 cycles received at: 2024-03-12 11:14:47.909000
#
# 10 cycles received at: 2024-03-12 11:14:48.108999
#
# 10 cycles received at: 2024-03-12 11:14:48.309000
#
# 10 cycles received at: 2024-03-12 11:14:48.509001
#
# 10 cycles received at: 2024-03-12 11:14:48.709000
#
# 10 cycles received at: 2024-03-12 11:14:48.909000
# Sag Start: 2024-03-12 11:14:49.079000
# Sag End: 2024-03-12 11:14:49.099001
# Interruption Start: 2024-03-12 11:14:49.099001
#
# *********************************************************************************
# Sag Duration: 0:00:00.020001
# Retained Voltage: 23.655662404047128
# Sag Type: Instantaneous
# *********************************************************************************
#
# 10 cycles received at: 2024-03-12 11:14:49.108999
#
# 10 cycles received at: 2024-03-12 11:14:49.309000
#
# 10 cycles received at: 2024-03-12 11:14:49.509001
#
# 10 cycles received at: 2024-03-12 11:14:49.709000
#
# 10 cycles received at: 2024-03-12 11:14:49.909000
#
# 10 cycles received at: 2024-03-12 11:14:50.108999
#
# 10 cycles received at: 2024-03-12 11:14:50.309000
#
# 10 cycles received at: 2024-03-12 11:14:50.509001
#
# 10 cycles received at: 2024-03-12 11:14:50.709000
#
# 10 cycles received at: 2024-03-12 11:14:50.909000
#
# 10 cycles received at: 2024-03-12 11:14:51.108999
#
# 10 cycles received at: 2024-03-12 11:14:51.309000
#
# 10 cycles received at: 2024-03-12 11:14:51.509001
#
# 10 cycles received at: 2024-03-12 11:14:51.709000
#
# 10 cycles received at: 2024-03-12 11:14:51.909000
#
# 10 cycles received at: 2024-03-12 11:14:52.108999
#
# 10 cycles received at: 2024-03-12 11:14:52.309000
#
# 10 cycles received at: 2024-03-12 11:14:52.509001
#
# 10 cycles received at: 2024-03-12 11:14:52.709000
#
# 10 cycles received at: 2024-03-12 11:14:52.909000
#
# 10 cycles received at: 2024-03-12 11:14:53.108999
#
# 10 cycles received at: 2024-03-12 11:14:53.309000
#
# 10 cycles received at: 2024-03-12 11:14:53.509001
#
# 10 cycles received at: 2024-03-12 11:14:53.709000
#
# 10 cycles received at: 2024-03-12 11:14:53.909000
#
# 10 cycles received at: 2024-03-12 11:14:54.108999
#
# 10 cycles received at: 2024-03-12 11:14:54.309000
#
# 10 cycles received at: 2024-03-12 11:14:54.509001
#
# 10 cycles received at: 2024-03-12 11:14:54.709000
#
# 10 cycles received at: 2024-03-12 11:14:54.909000
#
# 10 cycles received at: 2024-03-12 11:14:55.108999
#
# 10 cycles received at: 2024-03-12 11:14:55.309000
#
# 10 cycles received at: 2024-03-12 11:14:55.509001
#
# 10 cycles received at: 2024-03-12 11:14:55.709000
#
# 10 cycles received at: 2024-03-12 11:14:55.909000
#
# 10 cycles received at: 2024-03-12 11:14:56.108999
#
# 10 cycles received at: 2024-03-12 11:14:56.309000
#
# 10 cycles received at: 2024-03-12 11:14:56.509001
#
# 10 cycles received at: 2024-03-12 11:14:56.709000
#
# 10 cycles received at: 2024-03-12 11:14:56.909000
#
# 10 cycles received at: 2024-03-12 11:14:57.108999
#
# 10 cycles received at: 2024-03-12 11:14:57.309000
#
# 10 cycles received at: 2024-03-12 11:14:57.509001
#
# 10 cycles received at: 2024-03-12 11:14:57.709000
#
# 10 cycles received at: 2024-03-12 11:14:57.909000
#
# 10 cycles received at: 2024-03-12 11:14:58.108999
#
# 10 cycles received at: 2024-03-12 11:14:58.309000
#
# 10 cycles received at: 2024-03-12 11:14:58.509001
#
# 10 cycles received at: 2024-03-12 11:14:58.709000
#
# 10 cycles received at: 2024-03-12 11:14:58.909000
#
# 10 cycles received at: 2024-03-12 11:14:59.108999
#
# 10 cycles received at: 2024-03-12 11:14:59.309000
#
# 10 cycles received at: 2024-03-12 11:14:59.509001
#
# 10 cycles received at: 2024-03-12 11:14:59.709000
#
# 10 cycles received at: 2024-03-12 11:14:59.909000
#
# 10 cycles received at: 2024-03-12 11:15:00.108999
#
# 10 cycles received at: 2024-03-12 11:15:00.309000
#
# 10 cycles received at: 2024-03-12 11:15:00.509001
#
# 10 cycles received at: 2024-03-12 11:15:00.709000
#
# 10 cycles received at: 2024-03-12 11:15:00.909000
#
# 10 cycles received at: 2024-03-12 11:15:01.108999
#
# 10 cycles received at: 2024-03-12 11:15:01.309000
#
# 10 cycles received at: 2024-03-12 11:15:01.509001
#
# 10 cycles received at: 2024-03-12 11:15:01.709000
#
# 10 cycles received at: 2024-03-12 11:15:01.909000
#
# 10 cycles received at: 2024-03-12 11:15:02.108999
#
# 10 cycles received at: 2024-03-12 11:15:02.309000
#
# 10 cycles received at: 2024-03-12 11:15:02.509001
#
# 10 cycles received at: 2024-03-12 11:15:02.709000
#
# 10 cycles received at: 2024-03-12 11:15:02.909000
#
# 10 cycles received at: 2024-03-12 11:15:03.108999
#
# 10 cycles received at: 2024-03-12 11:15:03.309000
#
# 10 cycles received at: 2024-03-12 11:15:03.509001
#
# 10 cycles received at: 2024-03-12 11:15:03.709000
#
# 10 cycles received at: 2024-03-12 11:15:03.909000
#
# 10 cycles received at: 2024-03-12 11:15:04.108999
#
# 10 cycles received at: 2024-03-12 11:15:04.309000
#
# 10 cycles received at: 2024-03-12 11:15:04.509001
#
# 10 cycles received at: 2024-03-12 11:15:04.709000
#
# 10 cycles received at: 2024-03-12 11:15:04.909000
#
# 10 cycles received at: 2024-03-12 11:15:05.108999
#
# 10 cycles received at: 2024-03-12 11:15:05.309000
#
# 10 cycles received at: 2024-03-12 11:15:05.509001
#
# 10 cycles received at: 2024-03-12 11:15:05.709000
#
# 10 cycles received at: 2024-03-12 11:15:05.909000
#
# 10 cycles received at: 2024-03-12 11:15:06.108999
#
# 10 cycles received at: 2024-03-12 11:15:06.309000
#
# 10 cycles received at: 2024-03-12 11:15:06.509001
#
# 10 cycles received at: 2024-03-12 11:15:06.709000
#
# 10 cycles received at: 2024-03-12 11:15:06.909000
#
# 10 cycles received at: 2024-03-12 11:15:07.108999
#
# 10 cycles received at: 2024-03-12 11:15:07.309000
#
# 10 cycles received at: 2024-03-12 11:15:07.509001
#
# 10 cycles received at: 2024-03-12 11:15:07.709000
#
# 10 cycles received at: 2024-03-12 11:15:07.909000
#
# 10 cycles received at: 2024-03-12 11:15:08.108999
#
# 10 cycles received at: 2024-03-12 11:15:08.309000
#
# 10 cycles received at: 2024-03-12 11:15:08.509001
#
# 10 cycles received at: 2024-03-12 11:15:08.709000
#
# 10 cycles received at: 2024-03-12 11:15:08.909000
#
# 10 cycles received at: 2024-03-12 11:15:09.108999
#
# 10 cycles received at: 2024-03-12 11:15:09.309000
#
# 10 cycles received at: 2024-03-12 11:15:09.509001
#
# 10 cycles received at: 2024-03-12 11:15:09.709000
#
# 10 cycles received at: 2024-03-12 11:15:09.909000
#
# 10 cycles received at: 2024-03-12 11:15:10.108999
#
# 10 cycles received at: 2024-03-12 11:15:10.309000
#
# 10 cycles received at: 2024-03-12 11:15:10.509001
#
# 10 cycles received at: 2024-03-12 11:15:10.709000
#
# 10 cycles received at: 2024-03-12 11:15:10.909000
#
# 10 cycles received at: 2024-03-12 11:15:11.108999
#
# 10 cycles received at: 2024-03-12 11:15:11.309000
#
# 10 cycles received at: 2024-03-12 11:15:11.509001
#
# 10 cycles received at: 2024-03-12 11:15:11.709000
#
# 10 cycles received at: 2024-03-12 11:15:11.909000
#
# 10 cycles received at: 2024-03-12 11:15:12.108999
#
# 10 cycles received at: 2024-03-12 11:15:12.309000
#
# 10 cycles received at: 2024-03-12 11:15:12.509001
#
# 10 cycles received at: 2024-03-12 11:15:12.709000
#
# 10 cycles received at: 2024-03-12 11:15:12.909000
#
# 10 cycles received at: 2024-03-12 11:15:13.108999
#
# 10 cycles received at: 2024-03-12 11:15:13.309000
#
# 10 cycles received at: 2024-03-12 11:15:13.509001
#
# 10 cycles received at: 2024-03-12 11:15:13.709000
#
# 10 cycles received at: 2024-03-12 11:15:13.909000
#
# 10 cycles received at: 2024-03-12 11:15:14.108999
#
# 10 cycles received at: 2024-03-12 11:15:14.309000
#
# 10 cycles received at: 2024-03-12 11:15:14.509001
#
# 10 cycles received at: 2024-03-12 11:15:14.709000
#
# 10 cycles received at: 2024-03-12 11:15:14.909000
#
# 10 cycles received at: 2024-03-12 11:15:15.108999
#
# 10 cycles received at: 2024-03-12 11:15:15.309000
#
# 10 cycles received at: 2024-03-12 11:15:15.509001
#
# 10 cycles received at: 2024-03-12 11:15:15.709000
#
# 10 cycles received at: 2024-03-12 11:15:15.909000
#
# 10 cycles received at: 2024-03-12 11:15:16.108999
#
# 10 cycles received at: 2024-03-12 11:15:16.309000
#
# 10 cycles received at: 2024-03-12 11:15:16.509001
#
# 10 cycles received at: 2024-03-12 11:15:16.709000
#
# 10 cycles received at: 2024-03-12 11:15:16.909000
#
# 10 cycles received at: 2024-03-12 11:15:17.108999
#
# 10 cycles received at: 2024-03-12 11:15:17.309000
#
# 10 cycles received at: 2024-03-12 11:15:17.509001
#
# 10 cycles received at: 2024-03-12 11:15:17.709000
#
# 10 cycles received at: 2024-03-12 11:15:17.909000
#
# 10 cycles received at: 2024-03-12 11:15:18.108999
#
# 10 cycles received at: 2024-03-12 11:15:18.309000
#
# 10 cycles received at: 2024-03-12 11:15:18.509001
#
# 10 cycles received at: 2024-03-12 11:15:18.709000
#
# 10 cycles received at: 2024-03-12 11:15:18.909000
#
# 10 cycles received at: 2024-03-12 11:15:19.108999
#
# 10 cycles received at: 2024-03-12 11:15:19.309000
#
# 10 cycles received at: 2024-03-12 11:15:19.509001
#
# 10 cycles received at: 2024-03-12 11:15:19.709000
#
# 10 cycles received at: 2024-03-12 11:15:19.909000
#
# 10 cycles received at: 2024-03-12 11:15:20.108999
#
# 10 cycles received at: 2024-03-12 11:15:20.309000
#
# 10 cycles received at: 2024-03-12 11:15:20.509001
#
# 10 cycles received at: 2024-03-12 11:15:20.709000
#
# 10 cycles received at: 2024-03-12 11:15:20.909000
#
# 10 cycles received at: 2024-03-12 11:15:21.108999
#
# 10 cycles received at: 2024-03-12 11:15:21.309000
#
# 10 cycles received at: 2024-03-12 11:15:21.509001
#
# 10 cycles received at: 2024-03-12 11:15:21.709000
#
# 10 cycles received at: 2024-03-12 11:15:21.909000
#
# 10 cycles received at: 2024-03-12 11:15:22.108999
#
# 10 cycles received at: 2024-03-12 11:15:22.309000
#
# 10 cycles received at: 2024-03-12 11:15:22.509001
#
# 10 cycles received at: 2024-03-12 11:15:22.709000
#
# 10 cycles received at: 2024-03-12 11:15:22.909000
#
# 10 cycles received at: 2024-03-12 11:15:23.108999
#
# 10 cycles received at: 2024-03-12 11:15:23.309000
#
# 10 cycles received at: 2024-03-12 11:15:23.509001
#
# 10 cycles received at: 2024-03-12 11:15:23.709000
#
# 10 cycles received at: 2024-03-12 11:15:23.909000
#
# 10 cycles received at: 2024-03-12 11:15:24.108999
#
# 10 cycles received at: 2024-03-12 11:15:24.309000
#
# 10 cycles received at: 2024-03-12 11:15:24.509001
#
# 10 cycles received at: 2024-03-12 11:15:24.709000
#
# 10 cycles received at: 2024-03-12 11:15:24.909000
#
# 10 cycles received at: 2024-03-12 11:15:25.108999
#
# 10 cycles received at: 2024-03-12 11:15:25.309000
#
# 10 cycles received at: 2024-03-12 11:15:25.509001
#
# 10 cycles received at: 2024-03-12 11:15:25.709000
#
# 10 cycles received at: 2024-03-12 11:15:25.909000
#
# 10 cycles received at: 2024-03-12 11:15:26.108999
#
# 10 cycles received at: 2024-03-12 11:15:26.309000
#
# 10 cycles received at: 2024-03-12 11:15:26.509001
#
# 10 cycles received at: 2024-03-12 11:15:26.709000
#
# 10 cycles received at: 2024-03-12 11:15:26.909000
#
# 10 cycles received at: 2024-03-12 11:15:27.108999
#
# 10 cycles received at: 2024-03-12 11:15:27.309000
#
# 10 cycles received at: 2024-03-12 11:15:27.509001
#
# 10 cycles received at: 2024-03-12 11:15:27.709000
#
# 10 cycles received at: 2024-03-12 11:15:27.909000
#
# 10 cycles received at: 2024-03-12 11:15:28.108999
#
# 10 cycles received at: 2024-03-12 11:15:28.309000
#
# 10 cycles received at: 2024-03-12 11:15:28.509001
#
# 10 cycles received at: 2024-03-12 11:15:28.709000
#
# 10 cycles received at: 2024-03-12 11:15:28.909000
#
# 10 cycles received at: 2024-03-12 11:15:29.108999
#
# 10 cycles received at: 2024-03-12 11:15:29.309000
#
# 10 cycles received at: 2024-03-12 11:15:29.509001
#
# 10 cycles received at: 2024-03-12 11:15:29.709000
#
# 10 cycles received at: 2024-03-12 11:15:29.909000
#
# 10 cycles received at: 2024-03-12 11:15:30.108999
#
# 10 cycles received at: 2024-03-12 11:15:30.309000
#
# 10 cycles received at: 2024-03-12 11:15:30.509001
#
# 10 cycles received at: 2024-03-12 11:15:30.709000
#
# 10 cycles received at: 2024-03-12 11:15:30.909000
#
# 10 cycles received at: 2024-03-12 11:15:31.108999
#
# 10 cycles received at: 2024-03-12 11:15:31.309000
#
# 10 cycles received at: 2024-03-12 11:15:31.509001
#
# 10 cycles received at: 2024-03-12 11:15:31.709000
#
# 10 cycles received at: 2024-03-12 11:15:31.909000
#
# 10 cycles received at: 2024-03-12 11:15:32.108999
#
# 10 cycles received at: 2024-03-12 11:15:32.309000
#
# 10 cycles received at: 2024-03-12 11:15:32.509001
#
# 10 cycles received at: 2024-03-12 11:15:32.709000
#
# 10 cycles received at: 2024-03-12 11:15:32.909000
#
# 10 cycles received at: 2024-03-12 11:15:33.108999
#
# 10 cycles received at: 2024-03-12 11:15:33.309000
#
# 10 cycles received at: 2024-03-12 11:15:33.509001
#
# 10 cycles received at: 2024-03-12 11:15:33.709000
#
# 10 cycles received at: 2024-03-12 11:15:33.909000
#
# 10 cycles received at: 2024-03-12 11:15:34.108999
#
# 10 cycles received at: 2024-03-12 11:15:34.309000
#
# 10 cycles received at: 2024-03-12 11:15:34.509001
#
# 10 cycles received at: 2024-03-12 11:15:34.709000
#
# 10 cycles received at: 2024-03-12 11:15:34.909000
#
# 10 cycles received at: 2024-03-12 11:15:35.108999
#
# 10 cycles received at: 2024-03-12 11:15:35.309000
#
# 10 cycles received at: 2024-03-12 11:15:35.509001
#
# 10 cycles received at: 2024-03-12 11:15:35.709000
#
# 10 cycles received at: 2024-03-12 11:15:35.909000
#
# 10 cycles received at: 2024-03-12 11:15:36.108999
#
# 10 cycles received at: 2024-03-12 11:15:36.309000
#
# 10 cycles received at: 2024-03-12 11:15:36.509001
#
# 10 cycles received at: 2024-03-12 11:15:36.709000
#
# 10 cycles received at: 2024-03-12 11:15:36.909000
#
# 10 cycles received at: 2024-03-12 11:15:37.108999
#
# 10 cycles received at: 2024-03-12 11:15:37.309000
#
# 10 cycles received at: 2024-03-12 11:15:37.509001
#
# 10 cycles received at: 2024-03-12 11:15:37.709000
#
# 10 cycles received at: 2024-03-12 11:15:37.909000
#
# 10 cycles received at: 2024-03-12 11:15:38.108999
#
# 10 cycles received at: 2024-03-12 11:15:38.309000
#
# 10 cycles received at: 2024-03-12 11:15:38.509001
#
# 10 cycles received at: 2024-03-12 11:15:38.709000
#
# 10 cycles received at: 2024-03-12 11:15:38.909000
#
# 10 cycles received at: 2024-03-12 11:15:39.108999
#
# 10 cycles received at: 2024-03-12 11:15:39.309000
#
# 10 cycles received at: 2024-03-12 11:15:39.509001
#
# 10 cycles received at: 2024-03-12 11:15:39.709000
#
# 10 cycles received at: 2024-03-12 11:15:39.909000
#
# 10 cycles received at: 2024-03-12 11:15:40.108999
#
# 10 cycles received at: 2024-03-12 11:15:40.309000
#
# 10 cycles received at: 2024-03-12 11:15:40.509001
#
# 10 cycles received at: 2024-03-12 11:15:40.709000
#
# 10 cycles received at: 2024-03-12 11:15:40.909000
#
# 10 cycles received at: 2024-03-12 11:15:41.108999
#
# 10 cycles received at: 2024-03-12 11:15:41.309000
#
# 10 cycles received at: 2024-03-12 11:15:41.509001
#
# 10 cycles received at: 2024-03-12 11:15:41.709000
#
# 10 cycles received at: 2024-03-12 11:15:41.909000
#
# 10 cycles received at: 2024-03-12 11:15:42.108999
#
# 10 cycles received at: 2024-03-12 11:15:42.309000
#
# 10 cycles received at: 2024-03-12 11:15:42.509001
#
# 10 cycles received at: 2024-03-12 11:15:42.709000
#
# 10 cycles received at: 2024-03-12 11:15:42.909000
#
# 10 cycles received at: 2024-03-12 11:15:43.108999
#
# 10 cycles received at: 2024-03-12 11:15:43.309000
#
# 10 cycles received at: 2024-03-12 11:15:43.509001
#
# 10 cycles received at: 2024-03-12 11:15:43.709000
#
# 10 cycles received at: 2024-03-12 11:15:43.909000
#
# 10 cycles received at: 2024-03-12 11:15:44.108999
#
# 10 cycles received at: 2024-03-12 11:15:44.309000
#
# 10 cycles received at: 2024-03-12 11:15:44.509001
#
# 10 cycles received at: 2024-03-12 11:15:44.709000
#
# 10 cycles received at: 2024-03-12 11:15:44.909000
#
# 10 cycles received at: 2024-03-12 11:15:45.108999
#
# 10 cycles received at: 2024-03-12 11:15:45.309000
#
# 10 cycles received at: 2024-03-12 11:15:45.509001
#
# 10 cycles received at: 2024-03-12 11:15:45.709000
#
# 10 cycles received at: 2024-03-12 11:15:45.909000
#
# 10 cycles received at: 2024-03-12 11:15:46.108999
#
# 10 cycles received at: 2024-03-12 11:15:46.309000
#
# 10 cycles received at: 2024-03-12 11:15:46.509001
#
# 10 cycles received at: 2024-03-12 11:15:46.709000
#
# 10 cycles received at: 2024-03-12 11:15:46.909000
#
# 10 cycles received at: 2024-03-12 11:15:47.108999
#
# 10 cycles received at: 2024-03-12 11:15:47.309000
#
# 10 cycles received at: 2024-03-12 11:15:47.509001
#
# 10 cycles received at: 2024-03-12 11:15:47.709000
#
# 10 cycles received at: 2024-03-12 11:15:47.909000
#
# 10 cycles received at: 2024-03-12 11:15:48.108999
#
# 10 cycles received at: 2024-03-12 11:15:48.309000
#
# 10 cycles received at: 2024-03-12 11:15:48.509001
#
# 10 cycles received at: 2024-03-12 11:15:48.709000
#
# 10 cycles received at: 2024-03-12 11:15:48.909000
#
# 10 cycles received at: 2024-03-12 11:15:49.108999
#
# 10 cycles received at: 2024-03-12 11:15:49.309000
#
# 10 cycles received at: 2024-03-12 11:15:49.509001
#
# 10 cycles received at: 2024-03-12 11:15:49.709000
#
# 10 cycles received at: 2024-03-12 11:15:49.909000
#
# 10 cycles received at: 2024-03-12 11:15:50.108999
#
# 10 cycles received at: 2024-03-12 11:15:50.309000
#
# 10 cycles received at: 2024-03-12 11:15:50.509001
#
# 10 cycles received at: 2024-03-12 11:15:50.709000
#
# 10 cycles received at: 2024-03-12 11:15:50.909000
#
# 10 cycles received at: 2024-03-12 11:15:51.108999
#
# 10 cycles received at: 2024-03-12 11:15:51.309000
#
# 10 cycles received at: 2024-03-12 11:15:51.509001
#
# 10 cycles received at: 2024-03-12 11:15:51.709000
#
# 10 cycles received at: 2024-03-12 11:15:51.909000
#
# 10 cycles received at: 2024-03-12 11:15:52.108999
#
# 10 cycles received at: 2024-03-12 11:15:52.309000
#
# 10 cycles received at: 2024-03-12 11:15:52.509001
#
# 10 cycles received at: 2024-03-12 11:15:52.709000
#
# 10 cycles received at: 2024-03-12 11:15:52.909000
#
# 10 cycles received at: 2024-03-12 11:15:53.108999
#
# 10 cycles received at: 2024-03-12 11:15:53.309000
#
# 10 cycles received at: 2024-03-12 11:15:53.509001
#
# 10 cycles received at: 2024-03-12 11:15:53.709000
#
# 10 cycles received at: 2024-03-12 11:15:53.909000
#
# 10 cycles received at: 2024-03-12 11:15:54.108999
#
# 10 cycles received at: 2024-03-12 11:15:54.309000
#
# 10 cycles received at: 2024-03-12 11:15:54.509001
#
# 10 cycles received at: 2024-03-12 11:15:54.709000
#
# 10 cycles received at: 2024-03-12 11:15:54.909000
#
# 10 cycles received at: 2024-03-12 11:15:55.108999
#
# 10 cycles received at: 2024-03-12 11:15:55.309000
#
# 10 cycles received at: 2024-03-12 11:15:55.509001
#
# 10 cycles received at: 2024-03-12 11:15:55.709000
#
# 10 cycles received at: 2024-03-12 11:15:55.909000
#
# 10 cycles received at: 2024-03-12 11:15:56.108999
#
# 10 cycles received at: 2024-03-12 11:15:56.309000
#
# 10 cycles received at: 2024-03-12 11:15:56.509001
#
# 10 cycles received at: 2024-03-12 11:15:56.709000
#
# 10 cycles received at: 2024-03-12 11:15:56.909000
#
# 10 cycles received at: 2024-03-12 11:15:57.108999
#
# 10 cycles received at: 2024-03-12 11:15:57.309000
#
# 10 cycles received at: 2024-03-12 11:15:57.509001
#
# 10 cycles received at: 2024-03-12 11:15:57.709000
#
# 10 cycles received at: 2024-03-12 11:15:57.909000
#
# 10 cycles received at: 2024-03-12 11:15:58.108999
#
# 10 cycles received at: 2024-03-12 11:15:58.309000
#
# 10 cycles received at: 2024-03-12 11:15:58.509001
#
# 10 cycles received at: 2024-03-12 11:15:58.709000
#
# 10 cycles received at: 2024-03-12 11:15:58.909000
#
# 10 cycles received at: 2024-03-12 11:15:59.108999
#
# 10 cycles received at: 2024-03-12 11:15:59.309000
#
# 10 cycles received at: 2024-03-12 11:15:59.509001
#
# 10 cycles received at: 2024-03-12 11:15:59.709000
#
# 10 cycles received at: 2024-03-12 11:15:59.909000
#
# 10 cycles received at: 2024-03-12 11:16:00.108999
#
# 10 cycles received at: 2024-03-12 11:16:00.309000
#
# 10 cycles received at: 2024-03-12 11:16:00.509001
#
# 10 cycles received at: 2024-03-12 11:16:00.709000
#
# 10 cycles received at: 2024-03-12 11:16:00.909000
#
# 10 cycles received at: 2024-03-12 11:16:01.108999
#
# 10 cycles received at: 2024-03-12 11:16:01.309000
#
# 10 cycles received at: 2024-03-12 11:16:01.509001
#
# 10 cycles received at: 2024-03-12 11:16:01.709000
#
# 10 cycles received at: 2024-03-12 11:16:01.909000
#
# 10 cycles received at: 2024-03-12 11:16:02.108999
#
# 10 cycles received at: 2024-03-12 11:16:02.309000
#
# 10 cycles received at: 2024-03-12 11:16:02.509001
#
# 10 cycles received at: 2024-03-12 11:16:02.709000
#
# 10 cycles received at: 2024-03-12 11:16:02.909000
#
# 10 cycles received at: 2024-03-12 11:16:03.108999
#
# 10 cycles received at: 2024-03-12 11:16:03.309000
#
# 10 cycles received at: 2024-03-12 11:16:03.509001
#
# 10 cycles received at: 2024-03-12 11:16:03.709000
#
# 10 cycles received at: 2024-03-12 11:16:03.909000
#
# 10 cycles received at: 2024-03-12 11:16:04.108999
#
# 10 cycles received at: 2024-03-12 11:16:04.309000
#
# 10 cycles received at: 2024-03-12 11:16:04.509001
#
# 10 cycles received at: 2024-03-12 11:16:04.709000
#
# 10 cycles received at: 2024-03-12 11:16:04.909000
#
# 10 cycles received at: 2024-03-12 11:16:05.108999
#
# 10 cycles received at: 2024-03-12 11:16:05.309000
#
# 10 cycles received at: 2024-03-12 11:16:05.509001
#
# 10 cycles received at: 2024-03-12 11:16:05.709000
#
# 10 cycles received at: 2024-03-12 11:16:05.909000
#
# 10 cycles received at: 2024-03-12 11:16:06.108999
#
# 10 cycles received at: 2024-03-12 11:16:06.309000
#
# 10 cycles received at: 2024-03-12 11:16:06.509001
#
# 10 cycles received at: 2024-03-12 11:16:06.709000
#
# 10 cycles received at: 2024-03-12 11:16:06.909000
#
# 10 cycles received at: 2024-03-12 11:16:07.108999
#
# 10 cycles received at: 2024-03-12 11:16:07.309000
#
# 10 cycles received at: 2024-03-12 11:16:07.509001
#
# 10 cycles received at: 2024-03-12 11:16:07.709000
#
# 10 cycles received at: 2024-03-12 11:16:07.909000
#
# 10 cycles received at: 2024-03-12 11:16:08.108999
#
# 10 cycles received at: 2024-03-12 11:16:08.309000
#
# 10 cycles received at: 2024-03-12 11:16:08.509001
#
# 10 cycles received at: 2024-03-12 11:16:08.709000
#
# 10 cycles received at: 2024-03-12 11:16:08.909000
#
# 10 cycles received at: 2024-03-12 11:16:09.108999
#
# 10 cycles received at: 2024-03-12 11:16:09.309000
#
# 10 cycles received at: 2024-03-12 11:16:09.509001
#
# 10 cycles received at: 2024-03-12 11:16:09.709000
#
# 10 cycles received at: 2024-03-12 11:16:09.909000
#
# 10 cycles received at: 2024-03-12 11:16:10.108999
#
# 10 cycles received at: 2024-03-12 11:16:10.309000
#
# 10 cycles received at: 2024-03-12 11:16:10.509001
#
# 10 cycles received at: 2024-03-12 11:16:10.709000
#
# 10 cycles received at: 2024-03-12 11:16:10.909000
#
# 10 cycles received at: 2024-03-12 11:16:11.108999
#
# 10 cycles received at: 2024-03-12 11:16:11.309000
#
# 10 cycles received at: 2024-03-12 11:16:11.509001
#
# 10 cycles received at: 2024-03-12 11:16:11.709000
#
# 10 cycles received at: 2024-03-12 11:16:11.909000
#
# 10 cycles received at: 2024-03-12 11:16:12.108999
#
# 10 cycles received at: 2024-03-12 11:16:12.309000
#
# 10 cycles received at: 2024-03-12 11:16:12.509001
#
# 10 cycles received at: 2024-03-12 11:16:12.709000
#
# 10 cycles received at: 2024-03-12 11:16:12.909000
#
# 10 cycles received at: 2024-03-12 11:16:13.108999
#
# 10 cycles received at: 2024-03-12 11:16:13.309000
#
# 10 cycles received at: 2024-03-12 11:16:13.509001
#
# 10 cycles received at: 2024-03-12 11:16:13.709000
#
# 10 cycles received at: 2024-03-12 11:16:13.909000
#
# 10 cycles received at: 2024-03-12 11:16:14.108999
#
# 10 cycles received at: 2024-03-12 11:16:14.309000
#
# 10 cycles received at: 2024-03-12 11:16:14.509001
#
# 10 cycles received at: 2024-03-12 11:16:14.709000
#
# 10 cycles received at: 2024-03-12 11:16:14.909000
#
# 10 cycles received at: 2024-03-12 11:16:15.108999
#
# 10 cycles received at: 2024-03-12 11:16:15.309000
#
# 10 cycles received at: 2024-03-12 11:16:15.509001
#
# 10 cycles received at: 2024-03-12 11:16:15.709000
#
# 10 cycles received at: 2024-03-12 11:16:15.909000
#
# 10 cycles received at: 2024-03-12 11:16:16.108999
#
# 10 cycles received at: 2024-03-12 11:16:16.309000
#
# 10 cycles received at: 2024-03-12 11:16:16.509001
#
# 10 cycles received at: 2024-03-12 11:16:16.709000
#
# 10 cycles received at: 2024-03-12 11:16:16.909000
#
# 10 cycles received at: 2024-03-12 11:16:17.108999
#
# 10 cycles received at: 2024-03-12 11:16:17.309000
#
# 10 cycles received at: 2024-03-12 11:16:17.509001
#
# 10 cycles received at: 2024-03-12 11:16:17.709000
#
# 10 cycles received at: 2024-03-12 11:16:17.909000
#
# 10 cycles received at: 2024-03-12 11:16:18.108999
# Sag Start: 2024-03-12 11:16:18.118999
# Interruption End: 2024-03-12 11:16:18.118999
#
# *********************************************************************************
# Interruption Duration: 0:01:29.019998
# Interruption Type: Long Term Sustained Interruption
# *********************************************************************************
# Sag End: 2024-03-12 11:16:18.139000
#
# *********************************************************************************
# Sag Duration: 0:00:00.020001
# Retained Voltage: 85.36153729954698
# Sag Type: Instantaneous
# *********************************************************************************
#
# 10 cycles received at: 2024-03-12 11:16:18.309000
#
# 10 cycles received at: 2024-03-12 11:16:18.509001
#
# 10 cycles received at: 2024-03-12 11:16:18.709000
#
# 10 cycles received at: 2024-03-12 11:16:18.909000
#
# 10 cycles received at: 2024-03-12 11:16:19.108999
#
# 10 cycles received at: 2024-03-12 11:16:19.309000
#
# 10 cycles received at: 2024-03-12 11:16:19.509001
#
# 10 cycles received at: 2024-03-12 11:16:19.709000
#
# 10 cycles received at: 2024-03-12 11:16:19.909000
#
# 10 cycles received at: 2024-03-12 11:16:20.108999
#
# 10 cycles received at: 2024-03-12 11:16:20.309000
#
# 10 cycles received at: 2024-03-12 11:16:20.509001
#
# 10 cycles received at: 2024-03-12 11:16:20.709000
#
# 10 cycles received at: 2024-03-12 11:16:20.909000
#
# 10 cycles received at: 2024-03-12 11:16:21.108999
#
# 10 cycles received at: 2024-03-12 11:16:21.309000
#
# 10 cycles received at: 2024-03-12 11:16:21.509001
#
# 10 cycles received at: 2024-03-12 11:16:21.709000
#
# 10 cycles received at: 2024-03-12 11:16:21.909000
#
# 10 cycles received at: 2024-03-12 11:16:22.108999
#
# 10 cycles received at: 2024-03-12 11:16:22.309000
#
# 10 cycles received at: 2024-03-12 11:16:22.509001
#
# 10 cycles received at: 2024-03-12 11:16:22.709000
#
# 10 cycles received at: 2024-03-12 11:16:22.909000
#
# 10 cycles received at: 2024-03-12 11:16:23.108999
#
# 10 cycles received at: 2024-03-12 11:16:23.309000
#
# 10 cycles received at: 2024-03-12 11:16:23.509001
#
# 10 cycles received at: 2024-03-12 11:16:23.709000
#
# 10 cycles received at: 2024-03-12 11:16:23.909000
#
# 10 cycles received at: 2024-03-12 11:16:24.108999
#
# 10 cycles received at: 2024-03-12 11:16:24.309000
#
# 10 cycles received at: 2024-03-12 11:16:24.509001
#
# 10 cycles received at: 2024-03-12 11:16:24.709000
#
# 10 cycles received at: 2024-03-12 11:16:24.909000
#
# 10 cycles received at: 2024-03-12 11:16:25.108999
#
# 10 cycles received at: 2024-03-12 11:16:25.309000
#
# 10 cycles received at: 2024-03-12 11:16:25.509001
#
# 10 cycles received at: 2024-03-12 11:16:25.709000
#
# 10 cycles received at: 2024-03-12 11:16:25.909000
#
# 10 cycles received at: 2024-03-12 11:16:26.108999
#
# 10 cycles received at: 2024-03-12 11:16:26.309000
#
# 10 cycles received at: 2024-03-12 11:16:26.509001
#
# 10 cycles received at: 2024-03-12 11:16:26.709000
#
# 10 cycles received at: 2024-03-12 11:16:26.909000
#
# 10 cycles received at: 2024-03-12 11:16:27.108999
#
# 10 cycles received at: 2024-03-12 11:16:27.309000
#
# 10 cycles received at: 2024-03-12 11:16:27.509001
#
# 10 cycles received at: 2024-03-12 11:16:27.709000
#
# 10 cycles received at: 2024-03-12 11:16:27.909000
#
# 10 cycles received at: 2024-03-12 11:16:28.108999
#
# 10 cycles received at: 2024-03-12 11:16:28.309000
#
# 10 cycles received at: 2024-03-12 11:16:28.509001
#
# 10 cycles received at: 2024-03-12 11:16:28.709000
#
# 10 cycles received at: 2024-03-12 11:16:28.909000
#
# 10 cycles received at: 2024-03-12 11:16:29.108999
#
# 10 cycles received at: 2024-03-12 11:16:29.309000
#
# 10 cycles received at: 2024-03-12 11:16:29.509001
#
# 10 cycles received at: 2024-03-12 11:16:29.709000
#
# 10 cycles received at: 2024-03-12 11:16:29.909000
#
# 10 cycles received at: 2024-03-12 11:16:30.108999
#
# 10 cycles received at: 2024-03-12 11:16:30.309000
#
# 10 cycles received at: 2024-03-12 11:16:30.509001
#
# 10 cycles received at: 2024-03-12 11:16:30.709000
#
# 10 cycles received at: 2024-03-12 11:16:30.909000
#
# 10 cycles received at: 2024-03-12 11:16:31.108999
#
# 10 cycles received at: 2024-03-12 11:16:31.309000
#
# 10 cycles received at: 2024-03-12 11:16:31.509001
#
# 10 cycles received at: 2024-03-12 11:16:31.709000
#
# 10 cycles received at: 2024-03-12 11:16:31.909000
#
# 10 cycles received at: 2024-03-12 11:16:32.108999
#
# 10 cycles received at: 2024-03-12 11:16:32.309000
#
# 10 cycles received at: 2024-03-12 11:16:32.509001
#
# 10 cycles received at: 2024-03-12 11:16:32.709000
# Swell Start: 2024-03-12 11:16:32.759001

# %%
# fig = plt.figure(figsize=(16, 8))
# plt.plot(V1_complete)

# plt.show()
