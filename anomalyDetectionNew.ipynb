# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import plotly.graph_objects as go

from scipy.fft import fft
from scipy.signal import butter,filtfilt

import time

# %matplotlib widget

# %%
def modifyTimestamps(df):

    df = df.dropna()
    df = df.drop(df.filter(regex='Name..').columns, axis=1)
    df = df.rename(columns={"Name": "Time"})

    return df


def LDAP_to_time(t_array):

    timestamp_array = []

    for timestamp in t_array:

        if type(timestamp) == pd._libs.tslibs.timestamps.Timestamp:
            timestamp_array.append(timestamp)

        else:
            value = datetime.datetime(1601, 1, 1) + datetime.timedelta(seconds=timestamp/10000000)
            timestamp_array.append(value)

    return np.asarray(timestamp_array)

# %%
def lowpass_filter(signal, cutoff, fs, order):

    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq

    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    y = filtfilt(b, a, signal)
    
    return y

# %%
def rms_variation(V_array, T_array, anomaly_meta_info):

    for i in np.arange(start=0, stop=len(V_array), step=200):

        start = i
        end = i + 400

        V_rms = np.sqrt(np.mean(np.square(V_array[start:end])))


        if (V_rms >= 1.1 * anomaly_meta_info['voltage_threshold']):

            # swell start
            if (anomaly_meta_info['swell_start'] == None) and (anomaly_meta_info['swell_end'] == None):
                anomaly_meta_info['swell_start'] = T_array[i]
                print(f"Swell Start: {anomaly_meta_info['swell_start']}")


            if (V_rms >= anomaly_meta_info['max_swell_value']):
                anomaly_meta_info['max_swell_value'] = V_rms



        if (V_rms < 1.1 * anomaly_meta_info['voltage_threshold']) and (V_rms >= 0.9 * anomaly_meta_info['voltage_threshold']):

            # sag end
            if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_end'] = T_array[i]
                print(f"Sag End: {anomaly_meta_info['sag_end']}")


            # swell end
            if (anomaly_meta_info['swell_start'] != None) and (anomaly_meta_info['swell_end'] == None):
                anomaly_meta_info['swell_end'] = T_array[i]
                print(f"Swell End: {anomaly_meta_info['swell_end']}")


                
        if (V_rms < 0.9 * anomaly_meta_info['voltage_threshold']) and (V_rms >= 0.1 * anomaly_meta_info['voltage_threshold']):

            # sag start
            if (anomaly_meta_info['sag_start'] == None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_start'] = T_array[i]
                print(f"Sag Start: {anomaly_meta_info['sag_start']}")


            if (V_rms <= anomaly_meta_info['min_sag_value']):
                anomaly_meta_info['min_sag_value'] = V_rms


            # interruption end
            if (anomaly_meta_info['interruption_start'] != None) and (anomaly_meta_info['interruption_end'] == None):
                anomaly_meta_info['interruption_end'] = T_array[i]
                print(f"Interruption End: {anomaly_meta_info['interruption_end']}")


        
        if (V_rms < 0.1 * anomaly_meta_info['voltage_threshold']):

            # sag end
            if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] == None):
                anomaly_meta_info['sag_end'] = T_array[i]
                print(f"Sag End: {anomaly_meta_info['sag_end']}")


            # interruption start
            if (anomaly_meta_info['interruption_start'] == None) and (anomaly_meta_info['interruption_end'] == None):
                anomaly_meta_info['interruption_start'] = T_array[i]
                print(f"Interruption Start: {anomaly_meta_info['interruption_start']}")



        # reporting detected sag
        if (anomaly_meta_info['sag_start'] != None) and (anomaly_meta_info['sag_end'] != None):
            sag_duration = anomaly_meta_info['sag_end'] - anomaly_meta_info['sag_start']

            print("\n*********************************************************************************")
            print(f"Sag Duration: {sag_duration}")
            print(f"Retained Voltage: {anomaly_meta_info['min_sag_value']}")

            if (sag_duration <= datetime.timedelta(seconds=0.599853)): print(f"Sag Type: Instantaneous")
            elif (sag_duration > datetime.timedelta(seconds=0.599853)) and (sag_duration <= datetime.timedelta(seconds=3)): print(f"Sag Type: Momentary")
            elif (sag_duration > datetime.timedelta(seconds=3)) and (sag_duration <= datetime.timedelta(minutes=1)): print(f"Sag Type: Temporary")
            elif (sag_duration > datetime.timedelta(minutes=1)): print(f"Sag Type: Long Term Undervoltage")
            print("*********************************************************************************")

            anomaly_meta_info['sag_start'] = None
            anomaly_meta_info['sag_end'] = None
            anomaly_meta_info['min_sag_value'] = 1000000.



        # reporting detected swell
        if (anomaly_meta_info['swell_start'] != None) and (anomaly_meta_info['swell_end'] != None):
            swell_duration = anomaly_meta_info['swell_end'] - anomaly_meta_info['swell_start']

            print("\n*********************************************************************************")
            print(f"Swell Duration: {swell_duration}")
            print(f"Retained Voltage: {anomaly_meta_info['max_swell_value']}")

            if (swell_duration <= datetime.timedelta(seconds=0.599853)): print(f"Swell Type: Instantaneous")
            elif (swell_duration > datetime.timedelta(seconds=0.599853)) and (swell_duration <= datetime.timedelta(seconds=3)): print(f"Swell Type: Momentary")
            elif (swell_duration > datetime.timedelta(seconds=3)) and (swell_duration <= datetime.timedelta(minutes=1)): print(f"Swell Type: Temporary")
            elif (swell_duration > datetime.timedelta(minutes=1)): print(f"Swell Type: Long Term Overvoltage")
            print("*********************************************************************************")

            anomaly_meta_info['swell_start'] = None
            anomaly_meta_info['swell_end'] = None
            anomaly_meta_info['max_swell_value'] = 0.



        # reporting detected interruption
        if (anomaly_meta_info['interruption_start'] != None) and (anomaly_meta_info['interruption_end'] != None):
            interruption_duration = anomaly_meta_info['interruption_end'] - anomaly_meta_info['interruption_start']

            print("\n*********************************************************************************")
            print(f"Interruption Duration: {interruption_duration}")

            if (interruption_duration <= datetime.timedelta(seconds=3)): print(f"Interruption Type: Momentary")
            elif (interruption_duration > datetime.timedelta(seconds=3)) and (interruption_duration <= datetime.timedelta(minutes=1)): print(f"Interruption Type: Temporary")
            elif (interruption_duration > datetime.timedelta(minutes=1)): print(f"Interruption Type: Long Term Sustained Interruption")
            print("*********************************************************************************")

            anomaly_meta_info['interruption_start'] = None
            anomaly_meta_info['interruption_end'] = None



    return anomaly_meta_info

# %%
def thd_variation(signal, anomaly_meta_info, fs=20000):

    X = fft(signal)
    N = len(X)
    n = np.arange(N)
    T = N/fs


    freq = (n/T)[1:int(N/2)] 
    freq_amplitudes = np.abs(X)[1:int(N/2)]

    sorted_indices = np.argsort(-freq_amplitudes)

    dominant_freq = freq[sorted_indices[0]]
    other_freq = freq[sorted_indices[1:]]

    anomaly_meta_info['dominant_freq'] = dominant_freq


    sq_sum = np.sum(np.square(freq_amplitudes))

    sq_prime = np.square(np.max(freq_amplitudes))
    sq_harmonics = sq_sum - sq_prime

    thd = 100 * np.sqrt(sq_harmonics / sq_prime)

    anomaly_meta_info['thd'] = thd


    # reporting detected prime harmonic variation
    if (dominant_freq != anomaly_meta_info['required_freq']): 

        print("\n*********************************************************************************")
        print(f"Prime Harmonic Variation")
        print(f"Dominant Frequency: {anomaly_meta_info['dominant_freq']}")
        print("*********************************************************************************")

    
    # reporting detected THD variation
    if (thd > anomaly_meta_info['thd_threshold']): 
        
        print("\n*********************************************************************************")
        print(f"THD Threshold Violated")
        print(f"THD: {anomaly_meta_info['thd']} %")
        print("*********************************************************************************")


    return anomaly_meta_info

# %%
def anomaly_detection(V_array, I_array, T_array, anomaly_meta_info):

    print(f'\n10 cycles received at: {T_array[0]}')


    V1_filt = lowpass_filter(signal=V_array, cutoff=500, fs=20000, order=2)
    I1_filt = lowpass_filter(signal=I_array, cutoff=500, fs=20000, order=2)


    anomaly_meta_info = rms_variation(V_array=V1_filt, T_array=T_array, anomaly_meta_info=anomaly_meta_info)
    anomaly_meta_info = thd_variation(signal=V1_filt, anomaly_meta_info=anomaly_meta_info)


    return anomaly_meta_info

# %%
df = pd.read_csv('Power Anomalies Simulations Data/AD3_data/2024_03_12/07_Frequency variation.csv', sep=';')
df = modifyTimestamps(df=df)

factor = 192.76315789473685

V1_complete = df['U_L1real'].iloc[:].to_numpy() * factor
I1_complete = df['I_L1real'].iloc[:].to_numpy()
T_complete = df['Time'].iloc[:].to_numpy()


anomaly_meta_info = {
    'voltage_threshold': 230.,

    'swell_start': None,
    'swell_end': None,
    'max_swell_value': 0.,

    'sag_start': None,
    'sag_end': None,
    'min_sag_value': 1000000.,

    'interruption_start': None,
    'interruption_end': None,

    'required_freq': 50.,
    'dominant_freq': None,

    'thd_threshold': 8.,
    'thd': None,
}

# %%
for i in np.arange(start=0, stop=len(V1_complete), step=4000):

    start = i
    end = start + 4000

    V1 = V1_complete[start:end]
    I1 = I1_complete[start:end]

    T1 = T_complete[start:end]
    T1 = LDAP_to_time(t_array=T1)

    if len(V1) >= 400:
        anomaly_meta_info = anomaly_detection(V_array=V1, I_array=I1, T_array=T1, anomaly_meta_info=anomaly_meta_info)

    # time.sleep(2)
# Out:
# 10 cycles received at: 2024-03-12 12:02:53.159000
#
# 10 cycles received at: 2024-03-12 12:02:53.358999
#
# 10 cycles received at: 2024-03-12 12:02:53.559000
#
# 10 cycles received at: 2024-03-12 12:02:53.759001
#
# 10 cycles received at: 2024-03-12 12:02:53.959000
#
# 10 cycles received at: 2024-03-12 12:02:54.159000
#
# 10 cycles received at: 2024-03-12 12:02:54.358999
#
# 10 cycles received at: 2024-03-12 12:02:54.559000
#
# 10 cycles received at: 2024-03-12 12:02:54.759001
#
# 10 cycles received at: 2024-03-12 12:02:54.959000
#
# 10 cycles received at: 2024-03-12 12:02:55.159000
#
# 10 cycles received at: 2024-03-12 12:02:55.358999
#
# 10 cycles received at: 2024-03-12 12:02:55.559000
#
# 10 cycles received at: 2024-03-12 12:02:55.759001
#
# 10 cycles received at: 2024-03-12 12:02:55.959000
#
# 10 cycles received at: 2024-03-12 12:02:56.159000
#
# 10 cycles received at: 2024-03-12 12:02:56.358999
#
# 10 cycles received at: 2024-03-12 12:02:56.559000
#
# 10 cycles received at: 2024-03-12 12:02:56.759001
#
# 10 cycles received at: 2024-03-12 12:02:56.959000
#
# 10 cycles received at: 2024-03-12 12:02:57.159000
#
# 10 cycles received at: 2024-03-12 12:02:57.358999
#
# 10 cycles received at: 2024-03-12 12:02:57.559000
#
# 10 cycles received at: 2024-03-12 12:02:57.759001
#
# 10 cycles received at: 2024-03-12 12:02:57.959000
#
# 10 cycles received at: 2024-03-12 12:02:58.159000
#
# 10 cycles received at: 2024-03-12 12:02:58.358999
#
# 10 cycles received at: 2024-03-12 12:02:58.559000
#
# 10 cycles received at: 2024-03-12 12:02:58.759001
#
# 10 cycles received at: 2024-03-12 12:02:58.959000
#
# 10 cycles received at: 2024-03-12 12:02:59.159000
#
# 10 cycles received at: 2024-03-12 12:02:59.358999
#
# 10 cycles received at: 2024-03-12 12:02:59.559000
#
# 10 cycles received at: 2024-03-12 12:02:59.759001
#
# 10 cycles received at: 2024-03-12 12:02:59.959000
#
# 10 cycles received at: 2024-03-12 12:03:00.159000
#
# 10 cycles received at: 2024-03-12 12:03:00.358999
#
# 10 cycles received at: 2024-03-12 12:03:00.559000
#
# 10 cycles received at: 2024-03-12 12:03:00.759001
#
# 10 cycles received at: 2024-03-12 12:03:00.959000
#
# 10 cycles received at: 2024-03-12 12:03:01.159000
#
# 10 cycles received at: 2024-03-12 12:03:01.358999
#
# 10 cycles received at: 2024-03-12 12:03:01.559000
#
# 10 cycles received at: 2024-03-12 12:03:01.759001
#
# 10 cycles received at: 2024-03-12 12:03:01.959000
#
# 10 cycles received at: 2024-03-12 12:03:02.159000
#
# 10 cycles received at: 2024-03-12 12:03:02.358999
#
# 10 cycles received at: 2024-03-12 12:03:02.559000
#
# 10 cycles received at: 2024-03-12 12:03:02.759001
#
# 10 cycles received at: 2024-03-12 12:03:02.959000
#
# 10 cycles received at: 2024-03-12 12:03:03.159000
#
# 10 cycles received at: 2024-03-12 12:03:03.358999
#
# 10 cycles received at: 2024-03-12 12:03:03.559000
#
# 10 cycles received at: 2024-03-12 12:03:03.759001
#
# 10 cycles received at: 2024-03-12 12:03:03.959000
#
# 10 cycles received at: 2024-03-12 12:03:04.159000
#
# 10 cycles received at: 2024-03-12 12:03:04.358999
#
# 10 cycles received at: 2024-03-12 12:03:04.559000
#
# 10 cycles received at: 2024-03-12 12:03:04.759001
#
# 10 cycles received at: 2024-03-12 12:03:04.959000
#
# 10 cycles received at: 2024-03-12 12:03:05.159000
#
# 10 cycles received at: 2024-03-12 12:03:05.358999
#
# 10 cycles received at: 2024-03-12 12:03:05.559000
#
# 10 cycles received at: 2024-03-12 12:03:05.759001
#
# 10 cycles received at: 2024-03-12 12:03:05.959000
#
# 10 cycles received at: 2024-03-12 12:03:06.159000
#
# 10 cycles received at: 2024-03-12 12:03:06.358999
#
# 10 cycles received at: 2024-03-12 12:03:06.559000
#
# 10 cycles received at: 2024-03-12 12:03:06.759001
#
# 10 cycles received at: 2024-03-12 12:03:06.959000
#
# 10 cycles received at: 2024-03-12 12:03:07.159000
#
# 10 cycles received at: 2024-03-12 12:03:07.358999
#
# 10 cycles received at: 2024-03-12 12:03:07.559000
#
# 10 cycles received at: 2024-03-12 12:03:07.759001
#
# 10 cycles received at: 2024-03-12 12:03:07.959000
#
# 10 cycles received at: 2024-03-12 12:03:08.159000
#
# 10 cycles received at: 2024-03-12 12:03:08.358999
#
# 10 cycles received at: 2024-03-12 12:03:08.559000
#
# 10 cycles received at: 2024-03-12 12:03:08.759001
#
# 10 cycles received at: 2024-03-12 12:03:08.959000
#
# 10 cycles received at: 2024-03-12 12:03:09.159000
#
# 10 cycles received at: 2024-03-12 12:03:09.358999
#
# 10 cycles received at: 2024-03-12 12:03:09.559000
#
# 10 cycles received at: 2024-03-12 12:03:09.759001
#
# 10 cycles received at: 2024-03-12 12:03:09.959000
#
# 10 cycles received at: 2024-03-12 12:03:10.159000
#
# 10 cycles received at: 2024-03-12 12:03:59.358999
#
# 10 cycles received at: 2024-03-12 12:03:59.559000
#
# 10 cycles received at: 2024-03-12 12:03:59.759001
#
# 10 cycles received at: 2024-03-12 12:03:59.959000
#
# 10 cycles received at: 2024-03-12 12:04:00.159000
#
# 10 cycles received at: 2024-03-12 12:04:00.358999
#
# 10 cycles received at: 2024-03-12 12:04:00.559000
#
# 10 cycles received at: 2024-03-12 12:04:00.759001
#
# 10 cycles received at: 2024-03-12 12:04:00.959000
#
# 10 cycles received at: 2024-03-12 12:04:01.159000
#
# 10 cycles received at: 2024-03-12 12:04:01.358999
#
# 10 cycles received at: 2024-03-12 12:04:01.559000
#
# 10 cycles received at: 2024-03-12 12:04:01.759001
#
# 10 cycles received at: 2024-03-12 12:04:01.959000
#
# 10 cycles received at: 2024-03-12 12:04:02.159000
#
# 10 cycles received at: 2024-03-12 12:04:02.358999
#
# 10 cycles received at: 2024-03-12 12:04:02.559000
#
# 10 cycles received at: 2024-03-12 12:04:02.759001
#
# 10 cycles received at: 2024-03-12 12:04:02.959000
#
# 10 cycles received at: 2024-03-12 12:04:03.159000
#
# 10 cycles received at: 2024-03-12 12:04:03.358999
#
# 10 cycles received at: 2024-03-12 12:04:03.559000
#
# 10 cycles received at: 2024-03-12 12:04:03.759001
#
# 10 cycles received at: 2024-03-12 12:04:03.959000
#
# 10 cycles received at: 2024-03-12 12:04:04.159000
#
# 10 cycles received at: 2024-03-12 12:04:04.358999
#
# 10 cycles received at: 2024-03-12 12:04:04.559000
#
# 10 cycles received at: 2024-03-12 12:04:04.759001
#
# 10 cycles received at: 2024-03-12 12:04:04.959000
#
# 10 cycles received at: 2024-03-12 12:04:05.159000
#
# 10 cycles received at: 2024-03-12 12:04:05.358999
#
# 10 cycles received at: 2024-03-12 12:04:05.559000
#
# 10 cycles received at: 2024-03-12 12:04:05.759001
#
# 10 cycles received at: 2024-03-12 12:04:05.959000
#
# 10 cycles received at: 2024-03-12 12:04:06.159000
#
# 10 cycles received at: 2024-03-12 12:04:06.358999
#
# 10 cycles received at: 2024-03-12 12:04:06.559000
#
# 10 cycles received at: 2024-03-12 12:04:06.759001
#
# 10 cycles received at: 2024-03-12 12:04:06.959000
#
# 10 cycles received at: 2024-03-12 12:04:07.159000
#
# 10 cycles received at: 2024-03-12 12:04:07.358999
#
# 10 cycles received at: 2024-03-12 12:04:07.559000
#
# 10 cycles received at: 2024-03-12 12:04:07.759001
#
# 10 cycles received at: 2024-03-12 12:04:07.959000
#
# 10 cycles received at: 2024-03-12 12:04:08.159000
#
# 10 cycles received at: 2024-03-12 12:04:08.358999
#
# 10 cycles received at: 2024-03-12 12:04:08.559000
#
# 10 cycles received at: 2024-03-12 12:04:08.759001
#
# 10 cycles received at: 2024-03-12 12:04:08.959000
#
# 10 cycles received at: 2024-03-12 12:04:09.159000
#
# 10 cycles received at: 2024-03-12 12:04:09.358999
#
# 10 cycles received at: 2024-03-12 12:04:09.559000
#
# 10 cycles received at: 2024-03-12 12:04:09.759001
#
# 10 cycles received at: 2024-03-12 12:04:09.959000
#
# 10 cycles received at: 2024-03-12 12:04:10.159000
#
# 10 cycles received at: 2024-03-12 12:04:10.358999
#
# 10 cycles received at: 2024-03-12 12:04:10.559000
#
# 10 cycles received at: 2024-03-12 12:04:10.759001
#
# 10 cycles received at: 2024-03-12 12:04:10.959000
#
# 10 cycles received at: 2024-03-12 12:04:11.159000
#
# 10 cycles received at: 2024-03-12 12:04:11.358999
#
# 10 cycles received at: 2024-03-12 12:04:11.559000
#
# 10 cycles received at: 2024-03-12 12:04:11.759001
#
# 10 cycles received at: 2024-03-12 12:04:11.959000
#
# 10 cycles received at: 2024-03-12 12:04:12.159000
#
# 10 cycles received at: 2024-03-12 12:04:12.358999
#
# 10 cycles received at: 2024-03-12 12:04:12.559000
#
# 10 cycles received at: 2024-03-12 12:04:12.759001
#
# 10 cycles received at: 2024-03-12 12:04:12.959000
#
# 10 cycles received at: 2024-03-12 12:04:13.159000
#
# 10 cycles received at: 2024-03-12 12:04:13.358999
#
# 10 cycles received at: 2024-03-12 12:04:13.559000
#
# 10 cycles received at: 2024-03-12 12:04:13.759001
#
# 10 cycles received at: 2024-03-12 12:04:13.959000
#
# 10 cycles received at: 2024-03-12 12:04:14.159000
#
# 10 cycles received at: 2024-03-12 12:04:14.358999
#
# 10 cycles received at: 2024-03-12 12:04:14.559000
#
# 10 cycles received at: 2024-03-12 12:04:14.759001
#
# 10 cycles received at: 2024-03-12 12:04:14.959000
#
# 10 cycles received at: 2024-03-12 12:04:15.159000
#
# 10 cycles received at: 2024-03-12 12:04:15.358999
#
# 10 cycles received at: 2024-03-12 12:04:15.559000
#
# 10 cycles received at: 2024-03-12 12:04:15.759001
#
# 10 cycles received at: 2024-03-12 12:04:15.959000
#
# 10 cycles received at: 2024-03-12 12:04:16.159000
#
# 10 cycles received at: 2024-03-12 12:04:16.358999
#
# 10 cycles received at: 2024-03-12 12:04:16.559000
#
# 10 cycles received at: 2024-03-12 12:04:16.759001
#
# 10 cycles received at: 2024-03-12 12:04:16.959000
#
# 10 cycles received at: 2024-03-12 12:04:17.159000
#
# 10 cycles received at: 2024-03-12 12:04:17.358999
#
# 10 cycles received at: 2024-03-12 12:04:17.559000
#
# 10 cycles received at: 2024-03-12 12:04:17.759001
#
# 10 cycles received at: 2024-03-12 12:04:17.959000
#
# 10 cycles received at: 2024-03-12 12:04:18.159000
#
# 10 cycles received at: 2024-03-12 12:04:18.358999
#
# 10 cycles received at: 2024-03-12 12:04:18.559000
#
# 10 cycles received at: 2024-03-12 12:04:18.759001
#
# 10 cycles received at: 2024-03-12 12:04:18.959000
#
# 10 cycles received at: 2024-03-12 12:04:19.159000
#
# 10 cycles received at: 2024-03-12 12:04:19.358999
#
# 10 cycles received at: 2024-03-12 12:04:19.559000
#
# 10 cycles received at: 2024-03-12 12:04:19.759001
#
# 10 cycles received at: 2024-03-12 12:04:19.959000
#
# 10 cycles received at: 2024-03-12 12:04:20.159000
#
# 10 cycles received at: 2024-03-12 12:04:20.358999
#
# 10 cycles received at: 2024-03-12 12:04:20.559000
#
# 10 cycles received at: 2024-03-12 12:04:20.759001
#
# 10 cycles received at: 2024-03-12 12:04:20.959000
#
# 10 cycles received at: 2024-03-12 12:04:21.159000
#
# 10 cycles received at: 2024-03-12 12:04:21.358999
#
# 10 cycles received at: 2024-03-12 12:04:21.559000
#
# 10 cycles received at: 2024-03-12 12:04:21.759001
#
# 10 cycles received at: 2024-03-12 12:04:21.959000
#
# 10 cycles received at: 2024-03-12 12:04:22.159000
#
# 10 cycles received at: 2024-03-12 12:04:22.358999
#
# 10 cycles received at: 2024-03-12 12:04:22.559000
#
# 10 cycles received at: 2024-03-12 12:04:22.759001
#
# 10 cycles received at: 2024-03-12 12:04:22.959000
#
# 10 cycles received at: 2024-03-12 12:04:23.159000
#
# 10 cycles received at: 2024-03-12 12:04:23.358999
#
# 10 cycles received at: 2024-03-12 12:04:23.559000
#
# 10 cycles received at: 2024-03-12 12:04:23.759001
#
# 10 cycles received at: 2024-03-12 12:04:23.959000
#
# 10 cycles received at: 2024-03-12 12:04:24.159000
#
# 10 cycles received at: 2024-03-12 12:04:24.358999
#
# 10 cycles received at: 2024-03-12 12:04:24.559000
#
# 10 cycles received at: 2024-03-12 12:04:24.759001
#
# 10 cycles received at: 2024-03-12 12:04:24.959000
#
# 10 cycles received at: 2024-03-12 12:04:25.159000
#
# 10 cycles received at: 2024-03-12 12:04:25.358999
#
# 10 cycles received at: 2024-03-12 12:04:25.559000
#
# 10 cycles received at: 2024-03-12 12:04:25.759001
#
# 10 cycles received at: 2024-03-12 12:04:25.959000
#
# 10 cycles received at: 2024-03-12 12:04:26.159000
#
# 10 cycles received at: 2024-03-12 12:04:26.358999
#
# 10 cycles received at: 2024-03-12 12:04:26.559000
#
# 10 cycles received at: 2024-03-12 12:04:26.759001
#
# 10 cycles received at: 2024-03-12 12:04:26.959000
#
# 10 cycles received at: 2024-03-12 12:04:27.159000
#
# 10 cycles received at: 2024-03-12 12:04:27.358999
#
# 10 cycles received at: 2024-03-12 12:04:27.559000
#
# 10 cycles received at: 2024-03-12 12:04:27.759001
#
# 10 cycles received at: 2024-03-12 12:04:27.959000
#
# 10 cycles received at: 2024-03-12 12:04:28.159000
#
# 10 cycles received at: 2024-03-12 12:04:28.358999
#
# 10 cycles received at: 2024-03-12 12:04:28.559000
#
# 10 cycles received at: 2024-03-12 12:04:28.759001
#
# 10 cycles received at: 2024-03-12 12:04:28.959000
#
# 10 cycles received at: 2024-03-12 12:04:29.159000
#
# 10 cycles received at: 2024-03-12 12:04:29.358999
#
# 10 cycles received at: 2024-03-12 12:04:29.559000
#
# 10 cycles received at: 2024-03-12 12:04:29.759001
#
# 10 cycles received at: 2024-03-12 12:04:29.959000
#
# 10 cycles received at: 2024-03-12 12:04:30.159000
#
# 10 cycles received at: 2024-03-12 12:04:30.358999
#
# 10 cycles received at: 2024-03-12 12:04:30.559000
#
# 10 cycles received at: 2024-03-12 12:04:30.759001
#
# 10 cycles received at: 2024-03-12 12:04:30.959000
#
# 10 cycles received at: 2024-03-12 12:04:31.159000
#
# 10 cycles received at: 2024-03-12 12:04:31.358999
#
# 10 cycles received at: 2024-03-12 12:04:31.559000
#
# 10 cycles received at: 2024-03-12 12:04:31.759001
#
# 10 cycles received at: 2024-03-12 12:04:31.959000
#
# 10 cycles received at: 2024-03-12 12:04:32.159000
#
# 10 cycles received at: 2024-03-12 12:04:32.358999
#
# 10 cycles received at: 2024-03-12 12:04:32.559000
#
# 10 cycles received at: 2024-03-12 12:04:32.759001
#
# 10 cycles received at: 2024-03-12 12:04:32.959000
#
# 10 cycles received at: 2024-03-12 12:04:33.159000
#
# 10 cycles received at: 2024-03-12 12:04:33.358999
#
# 10 cycles received at: 2024-03-12 12:04:33.559000
#
# 10 cycles received at: 2024-03-12 12:04:33.759001
#
# 10 cycles received at: 2024-03-12 12:04:33.959000
#
# 10 cycles received at: 2024-03-12 12:04:34.159000
#
# 10 cycles received at: 2024-03-12 12:04:34.358999
#
# 10 cycles received at: 2024-03-12 12:04:34.559000
#
# 10 cycles received at: 2024-03-12 12:04:34.759001
#
# 10 cycles received at: 2024-03-12 12:04:34.959000
#
# 10 cycles received at: 2024-03-12 12:04:35.159000
#
# 10 cycles received at: 2024-03-12 12:04:35.358999
#
# 10 cycles received at: 2024-03-12 12:04:35.559000
#
# 10 cycles received at: 2024-03-12 12:04:35.759001
#
# 10 cycles received at: 2024-03-12 12:04:35.959000
#
# 10 cycles received at: 2024-03-12 12:04:36.159000
#
# 10 cycles received at: 2024-03-12 12:04:36.358999
#
# 10 cycles received at: 2024-03-12 12:04:36.559000
#
# 10 cycles received at: 2024-03-12 12:04:36.759001
#
# 10 cycles received at: 2024-03-12 12:04:36.959000
#
# 10 cycles received at: 2024-03-12 12:04:37.159000
#
# 10 cycles received at: 2024-03-12 12:04:37.358999
#
# 10 cycles received at: 2024-03-12 12:04:37.559000
#
# 10 cycles received at: 2024-03-12 12:04:37.759001
#
# 10 cycles received at: 2024-03-12 12:04:37.959000
#
# 10 cycles received at: 2024-03-12 12:04:38.159000
#
# 10 cycles received at: 2024-03-12 12:04:38.358999
#
# 10 cycles received at: 2024-03-12 12:04:38.559000
#
# 10 cycles received at: 2024-03-12 12:04:38.759001
#
# 10 cycles received at: 2024-03-12 12:04:38.959000
#
# 10 cycles received at: 2024-03-12 12:04:39.159000
#
# 10 cycles received at: 2024-03-12 12:04:39.358999
#
# 10 cycles received at: 2024-03-12 12:04:39.559000
#
# 10 cycles received at: 2024-03-12 12:04:39.759001
#
# 10 cycles received at: 2024-03-12 12:04:39.959000
#
# 10 cycles received at: 2024-03-12 12:04:40.159000
#
# 10 cycles received at: 2024-03-12 12:04:40.358999
#
# 10 cycles received at: 2024-03-12 12:04:40.559000
#
# 10 cycles received at: 2024-03-12 12:04:40.759001
#
# 10 cycles received at: 2024-03-12 12:04:40.959000
#
# 10 cycles received at: 2024-03-12 12:04:41.159000
#
# 10 cycles received at: 2024-03-12 12:04:41.358999
#
# 10 cycles received at: 2024-03-12 12:04:41.559000
#
# 10 cycles received at: 2024-03-12 12:04:41.759001
#
# 10 cycles received at: 2024-03-12 12:04:41.959000
#
# 10 cycles received at: 2024-03-12 12:04:42.159000
#
# 10 cycles received at: 2024-03-12 12:04:42.358999
#
# 10 cycles received at: 2024-03-12 12:04:42.559000
#
# 10 cycles received at: 2024-03-12 12:04:42.759001
#
# 10 cycles received at: 2024-03-12 12:04:42.959000
#
# 10 cycles received at: 2024-03-12 12:04:43.159000
#
# 10 cycles received at: 2024-03-12 12:04:43.358999
#
# 10 cycles received at: 2024-03-12 12:04:43.559000
#
# 10 cycles received at: 2024-03-12 12:04:43.759001
#
# 10 cycles received at: 2024-03-12 12:04:43.959000
#
# 10 cycles received at: 2024-03-12 12:04:44.159000
#
# 10 cycles received at: 2024-03-12 12:04:44.358999
#
# 10 cycles received at: 2024-03-12 12:04:44.559000
#
# 10 cycles received at: 2024-03-12 12:04:44.759001
#
# 10 cycles received at: 2024-03-12 12:04:44.959000
#
# 10 cycles received at: 2024-03-12 12:04:45.159000
#
# 10 cycles received at: 2024-03-12 12:04:45.358999
#
# 10 cycles received at: 2024-03-12 12:04:45.559000
#
# 10 cycles received at: 2024-03-12 12:04:45.759001
#
# 10 cycles received at: 2024-03-12 12:04:45.959000
#
# 10 cycles received at: 2024-03-12 12:04:46.159000
#
# 10 cycles received at: 2024-03-12 12:04:46.358999
#
# 10 cycles received at: 2024-03-12 12:04:46.559000
#
# 10 cycles received at: 2024-03-12 12:04:46.759001
#
# 10 cycles received at: 2024-03-12 12:04:46.959000
#
# 10 cycles received at: 2024-03-12 12:04:47.159000
#
# 10 cycles received at: 2024-03-12 12:04:47.358999
#
# 10 cycles received at: 2024-03-12 12:04:47.559000
#
# 10 cycles received at: 2024-03-12 12:04:47.759001
#
# 10 cycles received at: 2024-03-12 12:04:47.959000
#
# 10 cycles received at: 2024-03-12 12:04:48.159000
#
# 10 cycles received at: 2024-03-12 12:04:48.358999
#
# 10 cycles received at: 2024-03-12 12:04:48.559000
#
# 10 cycles received at: 2024-03-12 12:04:48.759001
#
# 10 cycles received at: 2024-03-12 12:04:48.959000
#
# 10 cycles received at: 2024-03-12 12:04:49.159000
#
# 10 cycles received at: 2024-03-12 12:04:49.358999
#
# 10 cycles received at: 2024-03-12 12:04:49.559000
#
# 10 cycles received at: 2024-03-12 12:04:49.759001
#
# 10 cycles received at: 2024-03-12 12:04:49.959000
#
# 10 cycles received at: 2024-03-12 12:04:50.159000
#
# 10 cycles received at: 2024-03-12 12:04:50.358999
#
# 10 cycles received at: 2024-03-12 12:04:50.559000
#
# 10 cycles received at: 2024-03-12 12:04:50.759001
#
# 10 cycles received at: 2024-03-12 12:04:50.959000
#
# 10 cycles received at: 2024-03-12 12:04:51.159000
#
# 10 cycles received at: 2024-03-12 12:04:51.358999
#
# 10 cycles received at: 2024-03-12 12:04:51.559000
#
# 10 cycles received at: 2024-03-12 12:04:51.759001
#
# 10 cycles received at: 2024-03-12 12:04:51.959000
#
# 10 cycles received at: 2024-03-12 12:04:52.159000
#
# 10 cycles received at: 2024-03-12 12:04:52.358999
#
# 10 cycles received at: 2024-03-12 12:04:52.559000
#
# 10 cycles received at: 2024-03-12 12:04:52.759001
#
# 10 cycles received at: 2024-03-12 12:04:52.959000
#
# 10 cycles received at: 2024-03-12 12:04:53.159000

# %%
# fig = plt.figure(figsize=(16, 8))
# plt.plot(V1_complete)

# plt.show()
